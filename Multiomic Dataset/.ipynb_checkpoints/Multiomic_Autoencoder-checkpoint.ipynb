# %% [markdown]
# ### Multi-omic Dataset: Latent representation using Autoencoders
# - Load Data
# - Normalize Data
# - Define Autoencoder Model
# - Train Autoencoder with normalized dataset
# - Use transformed dataset for classification
# - Use transformed dataset for clustering
# - Evaluation and Conclusions

# %%
import Models
import numpy as np
import random as rn
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

rn.seed(1)
np.random.seed(1)
tf.random.set_seed(1)
tf.config.threading.set_inter_op_parallelism_threads(1)
tf.config.threading.set_intra_op_parallelism_threads(1)

# Load Data
X_brca_mRNA_data = pd.read_csv('./BRCA_mRNA.txt', sep=',', index_col=0) # Dataset has Donor ID as first column
X_brca_CNA_data = pd.read_csv('./BRCA_CNA.txt', sep=',' ,index_col=0) # Dataset has Donor ID as first column
y_brca_data = pd.read_csv('./BRCA_Clinical.txt', sep=',', index_col=0, names=["Label"]) # Dataset has Donor ID on first column and Label on second column.

X_brca_mRNA_filtered = X_brca_mRNA_data.drop(["TCGA-AO-A12C-01","TCGA-AR-A1AT-01","TCGA-BH-A18V-06"], axis=1)
X_brca_CNA_filtered = X_brca_CNA_data.drop(["TCGA-AR-A0U1-01"], axis=1)
y_brca_filtered = y_brca_data.drop(["TCGA-AO-A12C-01","TCGA-AR-A1AT-01","TCGA-BH-A18V-06"], axis=0)


X_train_first_norm, X_train_second_norm, X_swapped_first_norm, X_swapped_second_norm, X_test_first_norm, X_test_second_norm, X_train_concat, X_swapped_concat, X_test_concat, y_train, y_test, y_train_oh, y_test_oh \
    = Models.prepare_datasets(X_brca_mRNA_filtered.T,X_brca_CNA_filtered.T, y_brca_filtered, test_size=0.2, swap_noise=0.15)
# Out:
# swapping: 20 rows.

# %%
## USEFUL TO CHECK SAMPLE DIFFERENCE
X_brca_CNA_filtered = X_brca_CNA_filtered[X_brca_CNA_filtered.columns.difference(X_brca_mRNA_data.columns)]
X_brca_mRNA_filtered = X_brca_mRNA_filtered[X_brca_mRNA_filtered.columns.difference(X_brca_CNA_data.columns)]

## CONCAT DATASETS
pd.concat([X_brca_mRNA_filtered.T, X_brca_CNA_filtered.T],axis=1)
# Out:
#              DonorID  Label
# 0    TCGA-3C-AAAU-01      0
# 1    TCGA-3C-AALI-01      0
# 2    TCGA-A1-A0SK-01      1
# 3    TCGA-A2-A04N-01      0
# 4    TCGA-A2-A04P-01      1
# ..               ...    ...
# 161  TCGA-PE-A5DD-01      0
# 162  TCGA-PE-A5DE-01      0
# 163  TCGA-UU-A93S-01      1
# 164  TCGA-Z7-A8R5-01      0
# 165  TCGA-Z7-A8R6-01      0
#
# [166 rows x 2 columns]

# %%
import importlib
importlib.reload(Models)
# Out:
# <module 'Models' from 'C:\\Desarrollo\\Data Science\\Jupyter Notebooks\\Stage\\oss-stage-2019\\Multiomic Dataset\\Models.py'>

# %%
###  Hyperparameter tuning

encoding_dims=[150]
mus=[0,0.1,0.3,0.5,0.7,0.9,1]
dropouts = [0.25]
l1s = [0.00005]
l2s = [0.000003]
scores = []
for encoding_dim in encoding_dims:
    for mu in mus:
        for dropout in dropouts:
            for l1 in l1s:
                for l2 in l2s:
                    ## Build and Train Autoencoder
                    autoencoder, encoder, decoder, loss = Models.build_and_train_multi_autoencoder([X_train_first_norm,X_train_second_norm],
                                                                                  [X_train_first_norm,X_train_second_norm],
                                                                                  encoding_dim=encoding_dim, 
                                                                                  regularizer=tf.keras.regularizers.l1_l2(l1,l2),
                                                                                  dropout=dropout,
                                                                                  epochs=200,
                                                                                  mu=mu)
                    ## Encode datasets
                    X_latent_multi_ae = Models.encode_dataset([X_train_first_norm,X_train_second_norm], encoder)
                    X_latent_test_multi_ae = Models.encode_dataset([X_test_first_norm,X_test_second_norm], encoder)

                    ## PCA ON AUTOENCODER LATENT SPACE
                    X_latent_pca_ae, X_latent_test_pca_ae = Models.perform_PCA(X_latent_multi_ae, X_latent_test_multi_ae, y_train, y_test, n_components=10)

                    ### CLASSIFICATION ###
                    classify = Models.classify(X_latent_multi_ae, X_latent_test_multi_ae, np.ravel(y_train), np.ravel(y_test), model_type="AE")

                    ### CLUSTERING ###
                    clustering = Models.cluster(X_latent_multi_ae,np.ravel(y_train), model_type="AE")

                    scores.append([mu,dropout,l1,l2,loss] + classify + clustering)
# Out:
# Compression: 1058.8
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'pandas.core.frame.DataFrame'>"}), <class 'NoneType'>
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# Epoch 00097: early stopping
# 0.03374212882839717
# PCA on single-modal explained variance ratio: 0.9999999403953552
# Results for AE:
#
# Best score for training data: 0.6076923076923076
#
# Best C: 0.08
# [[18  2]
#  [11  2]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.90      0.73        20
#            1       0.50      0.15      0.24        13
#
#     accuracy                           0.61        33
#    macro avg       0.56      0.53      0.48        33
# weighted avg       0.57      0.61      0.54        33
#
# Training set score for Logistic Regression: 0.600000
# Testing  set score for Logistic Regression: 0.606061
# Best score for training data: 0.5923076923076923
#
# Best C: 0.1
#
# Best Gamma: scale
# [[20  0]
#  [13  0]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.75        20
#            1       0.00      0.00      0.00        13
#
#     accuracy                           0.61        33
#    macro avg       0.30      0.50      0.38        33
# weighted avg       0.37      0.61      0.46        33
#
# Training set score for SVM: 0.592308
# Testing  set score for SVM: 0.606061
# C:\Users\Tomas\Anaconda3\envs\tensorflow_2\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Best score for training data: 0.5615384615384615
#
# Best #estimators: 140
#
# Best max depth: None
# [[13  7]
#  [ 7  6]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.65      0.65        20
#            1       0.46      0.46      0.46        13
#
#     accuracy                           0.58        33
#    macro avg       0.56      0.56      0.56        33
# weighted avg       0.58      0.58      0.58        33
#
# Training set score for RFC: 1.000000
# Testing  set score for RFC: 0.575758
# mutual information: 0.05890565000285271
# AE 2 clusters -  silhoutte score: 0.526997983455658
# AE 3 clusters -  silhoutte score: 0.4321152865886688
# AE 4 clusters -  silhoutte score: 0.3801265358924866
# AE 5 clusters -  silhoutte score: 0.40462765097618103
# AE 6 clusters -  silhoutte score: 0.3612890839576721
# mutual information: 0.044553274317791054
# AE 2 clusters -  silhoutte score: 0.5263761281967163
# AE 3 clusters -  silhoutte score: 0.40567493438720703
# AE 4 clusters -  silhoutte score: 0.4072485864162445
# AE 5 clusters -  silhoutte score: 0.3447611331939697
# AE 6 clusters -  silhoutte score: 0.28045836091041565
# mutual information: 0.0939237858898124
# AE 2 clusters -  silhoutte score: 0.4954583942890167
# AE 3 clusters -  silhoutte score: 0.4273918867111206
# AE 4 clusters -  silhoutte score: 0.4381532073020935
# AE 5 clusters -  silhoutte score: 0.3764055371284485
# AE 6 clusters -  silhoutte score: 0.3436697721481323
# Compression: 529.4
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'pandas.core.frame.DataFrame'>"}), <class 'NoneType'>
#
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00109: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00127: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 00132: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
#
# Epoch 00138: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# Epoch 00138: early stopping
# 0.02720106800015156
# PCA on single-modal explained variance ratio: 0.9994279742240906
# Results for AE:
#
# Best score for training data: 0.6153846153846153
#
# Best C: 0.08
# [[17  3]
#  [11  2]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.85      0.71        20
#            1       0.40      0.15      0.22        13
#
#     accuracy                           0.58        33
#    macro avg       0.50      0.50      0.47        33
# weighted avg       0.53      0.58      0.52        33
#
# Training set score for Logistic Regression: 0.661538
# Testing  set score for Logistic Regression: 0.575758
# Best score for training data: 0.5923076923076923
#
# Best C: 0.1
#
# Best Gamma: scale
# [[20  0]
#  [13  0]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.75        20
#            1       0.00      0.00      0.00        13
#
#     accuracy                           0.61        33
#    macro avg       0.30      0.50      0.38        33
# weighted avg       0.37      0.61      0.46        33
#
# Training set score for SVM: 0.592308
# Testing  set score for SVM: 0.606061
# C:\Users\Tomas\Anaconda3\envs\tensorflow_2\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Best score for training data: 0.5076923076923077
#
# Best #estimators: 140
#
# Best max depth: None
# [[14  6]
#  [ 6  7]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70        20
#            1       0.54      0.54      0.54        13
#
#     accuracy                           0.64        33
#    macro avg       0.62      0.62      0.62        33
# weighted avg       0.64      0.64      0.64        33
#
# Training set score for RFC: 1.000000
# Testing  set score for RFC: 0.636364
# mutual information: 0.050024135271024485
# AE 2 clusters -  silhoutte score: 0.39104360342025757
# AE 3 clusters -  silhoutte score: 0.3965912461280823
# AE 4 clusters -  silhoutte score: 0.37765762209892273
# AE 5 clusters -  silhoutte score: 0.36355286836624146
# AE 6 clusters -  silhoutte score: 0.36571216583251953
# mutual information: 0.09220464403823322
# AE 2 clusters -  silhoutte score: 0.40625908970832825
# AE 3 clusters -  silhoutte score: 0.3833143413066864
# AE 4 clusters -  silhoutte score: 0.368773877620697
# AE 5 clusters -  silhoutte score: 0.335334450006485
# AE 6 clusters -  silhoutte score: 0.3459088206291199
# mutual information: 0.054995305639563584
# AE 2 clusters -  silhoutte score: 0.3818807899951935
# AE 3 clusters -  silhoutte score: 0.3316412568092346
# AE 4 clusters -  silhoutte score: 0.3317403197288513
# AE 5 clusters -  silhoutte score: 0.35191085934638977
# AE 6 clusters -  silhoutte score: 0.31206461787223816
# Compression: 211.76
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'pandas.core.frame.DataFrame'>"}), <class 'NoneType'>
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00117: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 00122: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# Epoch 00122: early stopping
# 0.02688207173576722
# PCA on single-modal explained variance ratio: 0.9973476529121399
# Results for AE:
#
# Best score for training data: 0.6153846153846153
#
# Best C: 0.08
# [[18  2]
#  [11  2]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.90      0.73        20
#            1       0.50      0.15      0.24        13
#
#     accuracy                           0.61        33
#    macro avg       0.56      0.53      0.48        33
# weighted avg       0.57      0.61      0.54        33
#
# Training set score for Logistic Regression: 0.653846
# Testing  set score for Logistic Regression: 0.606061
# Best score for training data: 0.5923076923076923
#
# Best C: 0.1
#
# Best Gamma: scale
# [[20  0]
#  [13  0]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.75        20
#            1       0.00      0.00      0.00        13
#
#     accuracy                           0.61        33
#    macro avg       0.30      0.50      0.38        33
# weighted avg       0.37      0.61      0.46        33
#
# Training set score for SVM: 0.592308
# Testing  set score for SVM: 0.606061
# C:\Users\Tomas\Anaconda3\envs\tensorflow_2\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Best score for training data: 0.6538461538461539
#
# Best #estimators: 140
#
# Best max depth: None
# [[16  4]
#  [10  3]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.80      0.70        20
#            1       0.43      0.23      0.30        13
#
#     accuracy                           0.58        33
#    macro avg       0.52      0.52      0.50        33
# weighted avg       0.54      0.58      0.54        33
#
# Training set score for RFC: 1.000000
# Testing  set score for RFC: 0.575758
# mutual information: 0.0001007545818716402
# AE 2 clusters -  silhoutte score: 0.34849798679351807
# AE 3 clusters -  silhoutte score: 0.31608322262763977
# AE 4 clusters -  silhoutte score: 0.3025185167789459
# AE 5 clusters -  silhoutte score: 0.2891589105129242
# AE 6 clusters -  silhoutte score: 0.27921178936958313
# mutual information: 0.00045063599870930857
# AE 2 clusters -  silhoutte score: 0.3581019937992096
# AE 3 clusters -  silhoutte score: 0.3175622820854187
# AE 4 clusters -  silhoutte score: 0.2693920433521271
# AE 5 clusters -  silhoutte score: 0.2673145532608032
# AE 6 clusters -  silhoutte score: 0.27271971106529236
# mutual information: 0.00045063599870930857
# AE 2 clusters -  silhoutte score: 0.3581019937992096
# AE 3 clusters -  silhoutte score: 0.3158445954322815
# AE 4 clusters -  silhoutte score: 0.2935103178024292
# AE 5 clusters -  silhoutte score: 0.25997138023376465
# AE 6 clusters -  silhoutte score: 0.26023992896080017
# Compression: 105.88
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'pandas.core.frame.DataFrame'>"}), <class 'NoneType'>
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00128: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00140: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00147: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 00152: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# Epoch 00152: early stopping
# 0.02705172629883656
# PCA on single-modal explained variance ratio: 0.9963023066520691
# Results for AE:
#
# Best score for training data: 0.6615384615384615
#
# Best C: 0.08
# [[14  6]
#  [10  3]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.70      0.64        20
#            1       0.33      0.23      0.27        13
#
#     accuracy                           0.52        33
#    macro avg       0.46      0.47      0.45        33
# weighted avg       0.48      0.52      0.49        33
#
# Training set score for Logistic Regression: 0.715385
# Testing  set score for Logistic Regression: 0.515152
# Best score for training data: 0.6076923076923076
#
# Best C: 1.0
#
# Best Gamma: 0.1
# [[14  6]
#  [10  3]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.70      0.64        20
#            1       0.33      0.23      0.27        13
#
#     accuracy                           0.52        33
#    macro avg       0.46      0.47      0.45        33
# weighted avg       0.48      0.52      0.49        33
#
# Training set score for SVM: 0.700000
# Testing  set score for SVM: 0.515152
# Best score for training data: 0.5923076923076923
#
# Best #estimators: 100
#
# Best max depth: 12
# [[13  7]
#  [10  3]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.65      0.60        20
#            1       0.30      0.23      0.26        13
#
#     accuracy                           0.48        33
#    macro avg       0.43      0.44      0.43        33
# weighted avg       0.46      0.48      0.47        33
#
# Training set score for RFC: 0.992308
# Testing  set score for RFC: 0.484848
# mutual information: 9.063966487133176e-06
# AE 2 clusters -  silhoutte score: 0.37020131945610046
# AE 3 clusters -  silhoutte score: 0.34540891647338867
# AE 4 clusters -  silhoutte score: 0.35171669721603394
# AE 5 clusters -  silhoutte score: 0.3409193456172943
# AE 6 clusters -  silhoutte score: 0.3173755407333374
# mutual information: 0.0004450379324203158
# AE 2 clusters -  silhoutte score: 0.42772144079208374
# AE 3 clusters -  silhoutte score: 0.3135630488395691
# AE 4 clusters -  silhoutte score: 0.2859436869621277
# AE 5 clusters -  silhoutte score: 0.2718242406845093
# AE 6 clusters -  silhoutte score: 0.2642805278301239
# mutual information: 0.0007781607619702828
# AE 2 clusters -  silhoutte score: 0.42280733585357666
# AE 3 clusters -  silhoutte score: 0.3512021601200104
# AE 4 clusters -  silhoutte score: 0.32207342982292175
# AE 5 clusters -  silhoutte score: 0.3427688479423523
# AE 6 clusters -  silhoutte score: 0.332980751991272
# Compression: 70.58666666666667
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'pandas.core.frame.DataFrame'>"}), <class 'NoneType'>
#
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# Epoch 00131: early stopping
# 0.027098445422374284
# PCA on single-modal explained variance ratio: 0.947256863117218
# Results for AE:
#
# Best score for training data: 0.6461538461538462
#
# Best C: 0.08
# [[16  4]
#  [ 8  5]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73        20
#            1       0.56      0.38      0.45        13
#
#     accuracy                           0.64        33
#    macro avg       0.61      0.59      0.59        33
# weighted avg       0.62      0.64      0.62        33
#
# Training set score for Logistic Regression: 0.661538
# Testing  set score for Logistic Regression: 0.636364
# Best score for training data: 0.5923076923076923
#
# Best C: 0.1
#
# Best Gamma: scale
# [[20  0]
#  [13  0]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.75        20
#            1       0.00      0.00      0.00        13
#
#     accuracy                           0.61        33
#    macro avg       0.30      0.50      0.38        33
# weighted avg       0.37      0.61      0.46        33
#
# Training set score for SVM: 0.592308
# Testing  set score for SVM: 0.606061
# C:\Users\Tomas\Anaconda3\envs\tensorflow_2\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Best score for training data: 0.6307692307692309
#
# Best #estimators: 100
#
# Best max depth: 12
# [[17  3]
#  [ 8  5]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.85      0.76        20
#            1       0.62      0.38      0.48        13
#
#     accuracy                           0.67        33
#    macro avg       0.65      0.62      0.62        33
# weighted avg       0.66      0.67      0.65        33
#
# Training set score for RFC: 1.000000
# Testing  set score for RFC: 0.666667
# mutual information: 0.018663105022498763
# AE 2 clusters -  silhoutte score: 0.3151567876338959
# AE 3 clusters -  silhoutte score: 0.3206782937049866
# AE 4 clusters -  silhoutte score: 0.34562328457832336
# AE 5 clusters -  silhoutte score: 0.31670650839805603
# AE 6 clusters -  silhoutte score: 0.3175450265407562
# mutual information: 0.03133414798108025
# AE 2 clusters -  silhoutte score: 0.27452367544174194
# AE 3 clusters -  silhoutte score: 0.30586642026901245
# AE 4 clusters -  silhoutte score: 0.3041001558303833
# AE 5 clusters -  silhoutte score: 0.2835608124732971
# AE 6 clusters -  silhoutte score: 0.2466241717338562
# mutual information: 0.03235891996545215
# AE 2 clusters -  silhoutte score: 0.29859459400177
# AE 3 clusters -  silhoutte score: 0.319963663816452
# AE 4 clusters -  silhoutte score: 0.33159908652305603
# AE 5 clusters -  silhoutte score: 0.3340090215206146
# AE 6 clusters -  silhoutte score: 0.3178796172142029
# Compression: 52.94
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'pandas.core.frame.DataFrame'>"}), <class 'NoneType'>
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00110: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 00120: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
#
# Epoch 00125: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# Epoch 00125: early stopping
# 0.027231169062165113
# PCA on single-modal explained variance ratio: 0.9675343632698059
# Results for AE:
#
# Best score for training data: 0.6307692307692307
#
# Best C: 0.08
# [[18  2]
#  [10  3]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.90      0.75        20
#            1       0.60      0.23      0.33        13
#
#     accuracy                           0.64        33
#    macro avg       0.62      0.57      0.54        33
# weighted avg       0.63      0.64      0.59        33
#
# Training set score for Logistic Regression: 0.661538
# Testing  set score for Logistic Regression: 0.636364
# Best score for training data: 0.5923076923076923
#
# Best C: 0.1
#
# Best Gamma: scale
# [[20  0]
#  [13  0]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.75        20
#            1       0.00      0.00      0.00        13
#
#     accuracy                           0.61        33
#    macro avg       0.30      0.50      0.38        33
# weighted avg       0.37      0.61      0.46        33
#
# Training set score for SVM: 0.592308
# Testing  set score for SVM: 0.606061
# C:\Users\Tomas\Anaconda3\envs\tensorflow_2\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Best score for training data: 0.5538461538461539
#
# Best #estimators: 100
#
# Best max depth: 12
# [[13  7]
#  [ 9  4]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.65      0.62        20
#            1       0.36      0.31      0.33        13
#
#     accuracy                           0.52        33
#    macro avg       0.48      0.48      0.48        33
# weighted avg       0.50      0.52      0.51        33
#
# Training set score for RFC: 1.000000
# Testing  set score for RFC: 0.515152
# mutual information: 0.0002557917778618253
# AE 2 clusters -  silhoutte score: 0.43372291326522827
# AE 3 clusters -  silhoutte score: 0.4598882496356964
# AE 4 clusters -  silhoutte score: 0.4591461420059204
# AE 5 clusters -  silhoutte score: 0.41388773918151855
# AE 6 clusters -  silhoutte score: 0.3826856315135956
# mutual information: 0.004125304778353395
# AE 2 clusters -  silhoutte score: 0.24726234376430511
# AE 3 clusters -  silhoutte score: 0.4059754014015198
# AE 4 clusters -  silhoutte score: 0.4616090953350067
# AE 5 clusters -  silhoutte score: 0.4217028021812439
# AE 6 clusters -  silhoutte score: 0.41098132729530334
# mutual information: 0.0007371578043607703
# AE 2 clusters -  silhoutte score: 0.3988552689552307
# AE 3 clusters -  silhoutte score: 0.45475223660469055
# AE 4 clusters -  silhoutte score: 0.46128198504447937
# AE 5 clusters -  silhoutte score: 0.40489625930786133
# AE 6 clusters -  silhoutte score: 0.3703801929950714
# Compression: 35.29333333333334
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'pandas.core.frame.DataFrame'>"}), <class 'NoneType'>
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00108: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00114: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# Epoch 00125: early stopping
# 0.027248987985345034
# PCA on single-modal explained variance ratio: 0.9519343376159668
# Results for AE:
#
# Best score for training data: 0.5692307692307692
#
# Best C: 0.08
# [[11  9]
#  [ 9  4]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.55      0.55        20
#            1       0.31      0.31      0.31        13
#
#     accuracy                           0.45        33
#    macro avg       0.43      0.43      0.43        33
# weighted avg       0.45      0.45      0.45        33
#
# Training set score for Logistic Regression: 0.669231
# Testing  set score for Logistic Regression: 0.454545
# Best score for training data: 0.5923076923076923
#
# Best C: 0.1
#
# Best Gamma: scale
# [[20  0]
#  [13  0]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.75        20
#            1       0.00      0.00      0.00        13
#
#     accuracy                           0.61        33
#    macro avg       0.30      0.50      0.38        33
# weighted avg       0.37      0.61      0.46        33
#
# Training set score for SVM: 0.592308
# Testing  set score for SVM: 0.606061
# C:\Users\Tomas\Anaconda3\envs\tensorflow_2\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Best score for training data: 0.6307692307692307
#
# Best #estimators: 140
#
# Best max depth: None
# [[12  8]
#  [ 8  5]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60        20
#            1       0.38      0.38      0.38        13
#
#     accuracy                           0.52        33
#    macro avg       0.49      0.49      0.49        33
# weighted avg       0.52      0.52      0.52        33
#
# Training set score for RFC: 1.000000
# Testing  set score for RFC: 0.515152
# mutual information: 0.039629722793043234
# AE 2 clusters -  silhoutte score: 0.4934479892253876
# AE 3 clusters -  silhoutte score: 0.44189485907554626
# AE 4 clusters -  silhoutte score: 0.38186490535736084
# AE 5 clusters -  silhoutte score: 0.37505990266799927
# AE 6 clusters -  silhoutte score: 0.36230966448783875
# mutual information: 0.012291899938707598
# AE 2 clusters -  silhoutte score: 0.48585811257362366
# AE 3 clusters -  silhoutte score: 0.44189485907554626
# AE 4 clusters -  silhoutte score: 0.3797381818294525
# AE 5 clusters -  silhoutte score: 0.27528464794158936
# AE 6 clusters -  silhoutte score: 0.36641594767570496
# mutual information: 0.03104206128070465
# AE 2 clusters -  silhoutte score: 0.4304823577404022
# AE 3 clusters -  silhoutte score: 0.44189485907554626
# AE 4 clusters -  silhoutte score: 0.38104870915412903
# AE 5 clusters -  silhoutte score: 0.3778471052646637
# AE 6 clusters -  silhoutte score: 0.35397666692733765
# Compression: 26.47
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'pandas.core.frame.DataFrame'>"}), <class 'NoneType'>
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00101: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00112: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 00117: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# Epoch 00117: early stopping
# 0.026964302389667585
# PCA on single-modal explained variance ratio: 0.9855375289916992
# Results for AE:
#
# Best score for training data: 0.6
#
# Best C: 0.08
# [[14  6]
#  [ 8  5]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.70      0.67        20
#            1       0.45      0.38      0.42        13
#
#     accuracy                           0.58        33
#    macro avg       0.55      0.54      0.54        33
# weighted avg       0.56      0.58      0.57        33
#
# Training set score for Logistic Regression: 0.638462
# Testing  set score for Logistic Regression: 0.575758
# Best score for training data: 0.5923076923076923
#
# Best C: 0.1
#
# Best Gamma: scale
# [[20  0]
#  [13  0]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.75        20
#            1       0.00      0.00      0.00        13
#
#     accuracy                           0.61        33
#    macro avg       0.30      0.50      0.38        33
# weighted avg       0.37      0.61      0.46        33
#
# Training set score for SVM: 0.592308
# Testing  set score for SVM: 0.606061
# C:\Users\Tomas\Anaconda3\envs\tensorflow_2\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Best score for training data: 0.6230769230769231
#
# Best #estimators: 100
#
# Best max depth: 12
# [[15  5]
#  [ 9  4]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.75      0.68        20
#            1       0.44      0.31      0.36        13
#
#     accuracy                           0.58        33
#    macro avg       0.53      0.53      0.52        33
# weighted avg       0.55      0.58      0.56        33
#
# Training set score for RFC: 0.992308
# Testing  set score for RFC: 0.575758
# mutual information: 0.00872553581757903
# AE 2 clusters -  silhoutte score: 0.333331823348999
# AE 3 clusters -  silhoutte score: 0.37233829498291016
# AE 4 clusters -  silhoutte score: 0.3708685040473938
# AE 5 clusters -  silhoutte score: 0.33619213104248047
# AE 6 clusters -  silhoutte score: 0.32764294743537903
# mutual information: 0.03445841319818078
# AE 2 clusters -  silhoutte score: 0.38235655426979065
# AE 3 clusters -  silhoutte score: 0.30480799078941345
# AE 4 clusters -  silhoutte score: 0.2800869345664978
# AE 5 clusters -  silhoutte score: 0.2314482182264328
# AE 6 clusters -  silhoutte score: 0.22804908454418182
# mutual information: 0.03679765975344121
# AE 2 clusters -  silhoutte score: 0.33585599064826965
# AE 3 clusters -  silhoutte score: 0.3324802815914154
# AE 4 clusters -  silhoutte score: 0.3355960547924042
# AE 5 clusters -  silhoutte score: 0.2763030529022217
# AE 6 clusters -  silhoutte score: 0.2891479432582855

# %%
scores = pd.DataFrame(scores,
                      columns=["mu","dropout","l1","l2","loss","LR accuracy","SVM accuracy", "RF accuracy", "LR_auc", "SVM_auc", "RF_auc","kmeans_silhouette","kmeans_mutual_info","spectral_silhouette","spectral_mutual_info","hierarchical_silhouette","hierarchical_mutual_info"])    
scores
# Out:
#     mu  dropout       l1        l2      loss  LR accuracy  SVM accuracy  \
# 0  0.5     0.25  0.00005  0.000003  0.033742     0.606061      0.606061
# 1  0.5     0.25  0.00005  0.000003  0.027201     0.575758      0.606061
# 2  0.5     0.25  0.00005  0.000003  0.026882     0.606061      0.606061
# 3  0.5     0.25  0.00005  0.000003  0.027052     0.515152      0.515152
# 4  0.5     0.25  0.00005  0.000003  0.027098     0.636364      0.606061
# 5  0.5     0.25  0.00005  0.000003  0.027231     0.636364      0.606061
# 6  0.5     0.25  0.00005  0.000003  0.027249     0.454545      0.606061
# 7  0.5     0.25  0.00005  0.000003  0.026964     0.575758      0.606061
#
#    RF accuracy    LR_auc   SVM_auc    RF_auc  kmeans_silhouette  \
# 0     0.575758  0.403846  0.538462  0.509615           0.526998
# 1     0.636364  0.426923  0.561538  0.623077           0.391044
# 2     0.575758  0.515385  0.592308  0.563462           0.348498
# 3     0.484848  0.342308  0.442308  0.388462           0.370201
# 4     0.666667  0.726923  0.788462  0.780769           0.315157
# 5     0.515152  0.638462  0.596154  0.417308           0.433723
# 6     0.515152  0.311538  0.330769  0.453846           0.493448
# 7     0.575758  0.419231  0.484615  0.484615           0.333332
#
#    kmeans_mutual_info  spectral_silhouette  spectral_mutual_info  \
# 0            0.058906             0.526376              0.044553
# 1            0.050024             0.406259              0.092205
# 2            0.000101             0.358102              0.000451
# 3            0.000009             0.427721              0.000445
# 4            0.018663             0.274524              0.031334
# 5            0.000256             0.247262              0.004125
# 6            0.039630             0.485858              0.012292
# 7            0.008726             0.382357              0.034458
#
#    hierarchical_silhouette  hierarchical_mutual_info
# 0                 0.495458                  0.093924
# 1                 0.381881                  0.054995
# 2                 0.358102                  0.000451
# 3                 0.422807                  0.000778
# 4                 0.298595                  0.032359
# 5                 0.398855                  0.000737
# 6                 0.430482                  0.031042
# 7                 0.335856                  0.036798

# %%
scores.index = encoding_dims
data = scores[["LR accuracy","SVM accuracy","RF accuracy"]]

# %%
ax = sns.lineplot(data=data[["LR accuracy","SVM accuracy","RF accuracy"]])
plt.legend(fontsize='x-small')

# %% [markdown]
# ### Results
#
# | dim | mu  | l1      | l2      | Dropout | Loss   | Accuracy (LR) | Accuracy (SVM) | Accuracy (RF) | ROC-AUC (LR) | ROC-AUC (SVM) | ROC-AUC (RF) | SS (K-means) | MI (K-means) | SS (Spectral) | MI (Spectral) | SS (Hierarch.) | MI (Hierarch.) |
# |-----|-----|---------|---------|---------|--------|---------------|----------------|---------------|--------------|---------------|--------------|--------------|--------------|---------------|---------------|----------------|----------------|
# | 50  | 0.5 | 0       | 0       | 0.00    | 0.0159 |  0.57         | 0.63           | 0.57          | 0.5153       | 0.5346        | 0.5403       | 0.10         | 0.0764       | 0.11          | 0.0326        | 0.09           | 0.0454         |
# | 50  | 0.5 | 0       | 0       | 0.05    | 0.0189 |  0.60         | 0.66           | 0.51          | 0.4961       | 0.5961        | 0.4942       | 0.14         | 0.0003       | 0.14          | 0.0010        | 0.12           | 0.0027         |
# | 50  | 0.5 | 0       | 0       | 0.10    | 0.0220 |  0.57         | 0.57           | 0.45          | 0.4961       | 0.4923        | 0.4923       | 0.19         | 0.0221       | 0.19          | 0.0178        | 0.19           | 0.0122         |
# | 50  | 0.5 | 0       | 0       | 0.15    | 0.0227 |  0.63         | 0.57           | 0.57          | 0.5269       | 0.5692        | 0.4750       | 0.19         | 0.0009       | 0.20          | 0.0000        | 0.17           | 0.0081         |
# | 50  | 0.5 | 0       | 0       | 0.25    | 0.0240 |  0.66         | 0.60           | 0.57          | 0.4846       | 0.5615        | 0.6750       | 0.20         | 0.0000       | 0.20          | 0.0002        | 0.17           | 0.0012         |
# |-----|-----|---------|---------|---------|--------|---------------|----------------|---------------|--------------|---------------|--------------|--------------|--------------|---------------|---------------|----------------|----------------|
# | 50  | 0.5 | 0.00005 | 0       | 0.25    | 0.0270 |  0.63         | 0.60           | 0.54          | 0.4769       | 0.5384        | 0.5269       | 0.29         | 0.0000       | 0.29          | 0.0002        | 0.26           | 0.0087         |
# | 50  | 0.5 | 0.0002  | 0       | 0.25    | 0.0276 |  0.60         | 0.60           | 0.63          | 0.5269       | 0.4000        | 0.6461       | 0.40         | 0.0144       | 0.40          | 0.0144        | 0.38           | 0.0109         |
# |-----|-----|---------|---------|---------|--------|---------------|----------------|---------------|--------------|---------------|--------------|--------------|--------------|---------------|---------------|----------------|----------------|
# | 50  | 0.5 | 0.00005 | 0.000003| 0.25    | 0.0268 |  0.63         | 0.60           | 0.66          | 0.7153       | 0.7192        | 0.6750       | 0.39         | 0.0029       | 0.38          | 0.0018        | 0.36           | 0.0000         |
# |-----|-----|---------|---------|---------|--------|---------------|----------------|---------------|--------------|---------------|--------------|--------------|--------------|---------------|---------------|----------------|----------------|
# | 150 | 0.5 | 0.00005 | 0.000003| 0.25    | 0.0270 |  0.63         | 0.60           | 0.66          | 0.7269       | 0.7884        | 0.7807       | 0.31         | 0.0186       | 0.27          | 0.0313        | 0.29           | 0.0323         |

# %%
dropouts = [0.2,0.25]
l1s = [0.000005]
l2s = [0.000005,0.00001]
scores = []
for dropout in dropouts:
    for l1 in l1s:
        for l2 in l2s:
            ## Build and Train Autoencoder
            autoencoder, encoder, decoder, loss = Models.build_and_train_autoencoder(X_train_concat,
                                                                          X_train_concat,
                                                                          encoding_dim=100, 
                                                                          regularizer=tf.keras.regularizers.l1_l2(l1,l2),
                                                                          dropout=dropout,
                                                                          epochs=200)
            ## Encode datasets
            X_latent_ae = Models.encode_dataset(X_train_concat, encoder)
            X_latent_test_ae = Models.encode_dataset(X_test_concat, encoder)
         
            ## PCA ON AUTOENCODER LATENT SPACE
            X_latent_pca_ae, X_latent_test_pca_ae = Models.perform_PCA(X_latent_ae, X_latent_test_ae, y_train, y_test, n_components=10)

            ### CLASSIFICATION ###
            classify = Models.classify(X_latent_ae, X_latent_test_ae, np.ravel(y_train), np.ravel(y_test), model_type="AE")

            ### CLUSTERING ###
            clustering = Models.cluster(X_latent_ae,np.ravel(y_train_map), model_type="AE")

            scores.append([mu,dropout,l1,l2,loss] + classify + clustering)
# Out:
# Compression: 105.88
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# Epoch 00099: early stopping
# PCA on single-modal explained variance ratio: 0.9434438943862915
# Results for AE:
#
# Best score for training data: 0.6384615384615383
#
# Best C: 0.08
# [[18  2]
#  [10  3]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.90      0.75        20
#            1       0.60      0.23      0.33        13
#
#     accuracy                           0.64        33
#    macro avg       0.62      0.57      0.54        33
# weighted avg       0.63      0.64      0.59        33
#
# Training set score for Logistic Regression: 0.692308
# Testing  set score for Logistic Regression: 0.636364
# Best score for training data: 0.6153846153846153
#
# Best C: 1.0
#
# Best Gamma: 0.1
# [[18  2]
#  [ 9  4]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.90      0.77        20
#            1       0.67      0.31      0.42        13
#
#     accuracy                           0.67        33
#    macro avg       0.67      0.60      0.59        33
# weighted avg       0.67      0.67      0.63        33
#
# Training set score for SVM: 0.707692
# Testing  set score for SVM: 0.666667
# Best score for training data: 0.6076923076923078
#
# Best #estimators: 140
#
# Best max depth: None
# [[16  4]
#  [ 9  4]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.80      0.71        20
#            1       0.50      0.31      0.38        13
#
#     accuracy                           0.61        33
#    macro avg       0.57      0.55      0.55        33
# weighted avg       0.58      0.61      0.58        33
#
# Training set score for RFC: 1.000000
# Testing  set score for RFC: 0.606061
# mutual information: 0.03640088203412082
# AE 2 clusters -  silhoutte score: 0.16861486434936523
# AE 3 clusters -  silhoutte score: 0.17695584893226624
# AE 4 clusters -  silhoutte score: 0.18356095254421234
# AE 5 clusters -  silhoutte score: 0.19816945493221283
# AE 6 clusters -  silhoutte score: 0.2135956585407257
# mutual information: 0.0008743513391288293
# AE 2 clusters -  silhoutte score: 0.22366087138652802
# AE 3 clusters -  silhoutte score: 0.18038570880889893
# AE 4 clusters -  silhoutte score: 0.16400906443595886
# AE 5 clusters -  silhoutte score: 0.1729075163602829
# AE 6 clusters -  silhoutte score: 0.1864602267742157
# mutual information: 0.000668785402026461
# AE 2 clusters -  silhoutte score: 0.20892095565795898
# AE 3 clusters -  silhoutte score: 0.16451722383499146
# AE 4 clusters -  silhoutte score: 0.15569724142551422
# AE 5 clusters -  silhoutte score: 0.16698338091373444
# AE 6 clusters -  silhoutte score: 0.18048936128616333
# Compression: 105.88
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 00035: early stopping
# PCA on single-modal explained variance ratio: 0.9503766894340515
# Results for AE:
#
# Best score for training data: 0.6769230769230768
#
# Best C: 0.08
# [[14  6]
#  [10  3]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.70      0.64        20
#            1       0.33      0.23      0.27        13
#
#     accuracy                           0.52        33
#    macro avg       0.46      0.47      0.45        33
# weighted avg       0.48      0.52      0.49        33
#
# Training set score for Logistic Regression: 0.692308
# Testing  set score for Logistic Regression: 0.515152
# Best score for training data: 0.6615384615384615
#
# Best C: 1.0
#
# Best Gamma: 0.1
# [[16  4]
#  [ 9  4]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.80      0.71        20
#            1       0.50      0.31      0.38        13
#
#     accuracy                           0.61        33
#    macro avg       0.57      0.55      0.55        33
# weighted avg       0.58      0.61      0.58        33
#
# Training set score for SVM: 0.700000
# Testing  set score for SVM: 0.606061
# Best score for training data: 0.6307692307692307
#
# Best #estimators: 100
#
# Best max depth: 12
# [[14  6]
#  [ 9  4]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.70      0.65        20
#            1       0.40      0.31      0.35        13
#
#     accuracy                           0.55        33
#    macro avg       0.50      0.50      0.50        33
# weighted avg       0.53      0.55      0.53        33
#
# Training set score for RFC: 1.000000
# Testing  set score for RFC: 0.545455
# mutual information: 5.5064695756933674e-05
# AE 2 clusters -  silhoutte score: 0.22526131570339203
# AE 3 clusters -  silhoutte score: 0.2145080268383026
# AE 4 clusters -  silhoutte score: 0.22810588777065277
# AE 5 clusters -  silhoutte score: 0.2140297144651413
# AE 6 clusters -  silhoutte score: 0.2055792659521103
# mutual information: 0.000526849824188075
# AE 2 clusters -  silhoutte score: 0.21222643554210663
# AE 3 clusters -  silhoutte score: 0.2075367569923401
# AE 4 clusters -  silhoutte score: 0.21784764528274536
# AE 5 clusters -  silhoutte score: 0.2004804164171219
# AE 6 clusters -  silhoutte score: 0.21034693717956543
# mutual information: 0.005111811655926306
# AE 2 clusters -  silhoutte score: 0.2191045582294464
# AE 3 clusters -  silhoutte score: 0.1996162384748459
# AE 4 clusters -  silhoutte score: 0.19407248497009277
# AE 5 clusters -  silhoutte score: 0.18504013121128082
# AE 6 clusters -  silhoutte score: 0.19445577263832092
# Compression: 105.88
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 00070: early stopping
# PCA on single-modal explained variance ratio: 0.9412816762924194
# Results for AE:
#
# Best score for training data: 0.6153846153846153
#
# Best C: 0.08
# [[17  3]
#  [10  3]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.63      0.85      0.72        20
#            1       0.50      0.23      0.32        13
#
#     accuracy                           0.61        33
#    macro avg       0.56      0.54      0.52        33
# weighted avg       0.58      0.61      0.56        33
#
# Training set score for Logistic Regression: 0.638462
# Testing  set score for Logistic Regression: 0.606061
# Best score for training data: 0.5923076923076923
#
# Best C: 0.1
#
# Best Gamma: scale
# [[20  0]
#  [13  0]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.75        20
#            1       0.00      0.00      0.00        13
#
#     accuracy                           0.61        33
#    macro avg       0.30      0.50      0.38        33
# weighted avg       0.37      0.61      0.46        33
#
# Training set score for SVM: 0.592308
# Testing  set score for SVM: 0.606061
# C:\Users\Tomas\Anaconda3\envs\tensorflow_2\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Best score for training data: 0.6
#
# Best #estimators: 140
#
# Best max depth: None
# [[18  2]
#  [11  2]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.90      0.73        20
#            1       0.50      0.15      0.24        13
#
#     accuracy                           0.61        33
#    macro avg       0.56      0.53      0.48        33
# weighted avg       0.57      0.61      0.54        33
#
# Training set score for RFC: 1.000000
# Testing  set score for RFC: 0.606061
# mutual information: 0.021726669365613148
# AE 2 clusters -  silhoutte score: 0.19919610023498535
# AE 3 clusters -  silhoutte score: 0.2076071947813034
# AE 4 clusters -  silhoutte score: 0.2110196352005005
# AE 5 clusters -  silhoutte score: 0.20281586050987244
# AE 6 clusters -  silhoutte score: 0.2135675996541977
# mutual information: 0.0024726635852203344
# AE 2 clusters -  silhoutte score: 0.1891232132911682
# AE 3 clusters -  silhoutte score: 0.19977445900440216
# AE 4 clusters -  silhoutte score: 0.18769598007202148
# AE 5 clusters -  silhoutte score: 0.1822313815355301
# AE 6 clusters -  silhoutte score: 0.19865728914737701
# mutual information: 0.0009345880578005224
# AE 2 clusters -  silhoutte score: 0.17823882400989532
# AE 3 clusters -  silhoutte score: 0.19593843817710876
# AE 4 clusters -  silhoutte score: 0.17954638600349426
# AE 5 clusters -  silhoutte score: 0.1728825718164444
# AE 6 clusters -  silhoutte score: 0.19259074330329895
# Compression: 105.88
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00101: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 00109: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
#
# Epoch 00114: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# Epoch 00114: early stopping
# PCA on single-modal explained variance ratio: 0.9398872256278992
# Results for AE:
#
# Best score for training data: 0.6461538461538461
#
# Best C: 0.08
# [[17  3]
#  [11  2]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.85      0.71        20
#            1       0.40      0.15      0.22        13
#
#     accuracy                           0.58        33
#    macro avg       0.50      0.50      0.47        33
# weighted avg       0.53      0.58      0.52        33
#
# Training set score for Logistic Regression: 0.707692
# Testing  set score for Logistic Regression: 0.575758
# Best score for training data: 0.6307692307692306
#
# Best C: 1.0
#
# Best Gamma: 0.1
# [[16  4]
#  [11  2]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.80      0.68        20
#            1       0.33      0.15      0.21        13
#
#     accuracy                           0.55        33
#    macro avg       0.46      0.48      0.45        33
# weighted avg       0.49      0.55      0.50        33
#
# Training set score for SVM: 0.746154
# Testing  set score for SVM: 0.545455
# Best score for training data: 0.6230769230769231
#
# Best #estimators: 100
#
# Best max depth: 12
# [[14  6]
#  [12  1]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.70      0.61        20
#            1       0.14      0.08      0.10        13
#
#     accuracy                           0.45        33
#    macro avg       0.34      0.39      0.35        33
# weighted avg       0.38      0.45      0.41        33
#
# Training set score for RFC: 1.000000
# Testing  set score for RFC: 0.454545
# mutual information: 0.000209194501840825
# AE 2 clusters -  silhoutte score: 0.1969800740480423
# AE 3 clusters -  silhoutte score: 0.2072877436876297
# AE 4 clusters -  silhoutte score: 0.2269252985715866
# AE 5 clusters -  silhoutte score: 0.20932520925998688
# AE 6 clusters -  silhoutte score: 0.19602979719638824
# mutual information: 6.052810403441833e-05
# AE 2 clusters -  silhoutte score: 0.22212862968444824
# AE 3 clusters -  silhoutte score: 0.21611125767230988
# AE 4 clusters -  silhoutte score: 0.21691593527793884
# AE 5 clusters -  silhoutte score: 0.19927045702934265
# AE 6 clusters -  silhoutte score: 0.19357018172740936
# mutual information: 0.002832240480541993
# AE 2 clusters -  silhoutte score: 0.19699126482009888
# AE 3 clusters -  silhoutte score: 0.16120290756225586
# AE 4 clusters -  silhoutte score: 0.17030389606952667
# AE 5 clusters -  silhoutte score: 0.1683458536863327
# AE 6 clusters -  silhoutte score: 0.17185743153095245

# %%
scores = pd.DataFrame(scores,
                      columns=["mu","dropout","l1","l2","loss","LR_accuracy","SVM_accuracy", "RF_accuracy", "LR_auc", "SVM_auc", "RF_auc","kmeans_silhouette","kmeans_mutual_info","spectral_silhouette","spectral_mutual_info","hierarchical_silhouette","hierarchical_mutual_info"])    
scores
# Out:
#     mu  dropout        l1  l2      loss  LR_accuracy  SVM_accuracy  \
# 0  0.5     0.25  0.000000   0  0.022848     0.575758      0.575758
# 1  0.5     0.25  0.000001   0  0.030904     0.575758      0.575758
# 2  0.5     0.25  0.000005   0  0.036155     0.606061      0.606061
# 3  0.5     0.25  0.000010   0  0.032941     0.636364      0.606061
# 4  0.5     0.25  0.000050   0  0.026921     0.606061      0.606061
# 5  0.5     0.25  0.000100   0  0.027738     0.606061      0.606061
#
#    RF_accuracy    LR_auc   SVM_auc    RF_auc  kmeans_silhouette  \
# 0     0.606061  0.473077  0.496154  0.476923           0.208409
# 1     0.575758  0.546154  0.496154  0.594231           0.228330
# 2     0.606061  0.507692  0.534615  0.548077           0.253864
# 3     0.606061  0.469231  0.476923  0.494231           0.227300
# 4     0.393939  0.307692  0.376923  0.378846           0.427283
# 5     0.636364  0.576923  0.642308  0.600000           0.310373
#
#    kmeans_mutual_info  spectral_silhouette  spectral_mutual_info  \
# 0            0.000013             0.207419              0.000448
# 1            0.036401             0.226257              0.014883
# 2            0.000132             0.254855              0.000769
# 3            0.000590             0.242299              0.001734
# 4            0.016744             0.423750              0.009981
# 5            0.020668             0.314558              0.018793
#
#    hierarchical_silhouette  hierarchical_mutual_info
# 0                 0.194171                  0.000061
# 1                 0.207957                  0.033440
# 2                 0.223008                  0.003138
# 3                 0.209217                  0.002607
# 4                 0.417373                  0.014346
# 5                 0.295007                  0.004051
