# %% [markdown]
# ### Multi-omic Dataset: Latent representation using Autoencoders
# - Load Data
# - Normalize Data
# - Define, Train and Evaluate Classifier: Random Forest
# - Define, Train and Evaluate Classifier: XGBoost
# - Define, Train and Evaluate Classifier: DNN models
# - Evaluation and Conclusions

# %%
import numpy as np
import random as rn
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

rn.seed(1)
np.random.seed(1)
tf.random.set_seed(1)
tf.config.threading.set_inter_op_parallelism_threads(1)
tf.config.threading.set_intra_op_parallelism_threads(1)

# Load Data
X_renal_data = pd.read_csv('./x_exp_renal.csv', sep='\t') # Dataset has Donor ID as first column
y_renal_data = pd.read_csv('./y_renal.csv', sep=',') # Dataset has Donor ID on first column and Label on second column.

from sklearn.model_selection import train_test_split
# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_renal_data.iloc[:,1:],y_renal_data["label"],test_size=0.2, random_state=1) # Drop the Donor ID column from both datasets
# Normalization of data sets
# Data Scaling MinMax
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_norm = X_train
X_test_norm = X_test

X_train_norm = pd.DataFrame(scaler.fit_transform(X_train_norm))
X_test_norm = pd.DataFrame(scaler.transform(X_test_norm))

# We will use "X_train_norm" as training dataset

# %%
# Random Forest Classifier 
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(random_state=0, class_weight="balanced_subsample") # try class_weights "balanced" and "balanced_subsample"

# Perform CV to tune n_estimators for best RFC fit
params_grid = [{'n_estimators': [110, 120, 140], 'max_depth':[12,13,14]}]

# Perform Cross Validation Grid Search to find best hyperparamters
rfc_grid = GridSearchCV(estimator=rfc, param_grid=params_grid, cv=5)
rfc_grid.fit(X_train_norm, y_train)

# Print training scores
print('Best score for training data:', rfc_grid.best_score_,"\n") 
print('Best #estimators:',rfc_grid.best_estimator_.n_estimators,"\n") 
print('Best max depth:',rfc_grid.best_estimator_.max_depth,"\n") 

# Select the estimator with the best hyperparameters
final_rfc = rfc_grid.best_estimator_

# Predict classification with final model
y_pred = final_rfc.predict(X_test_norm)

cm = confusion_matrix(y_test,y_pred)

print(cm)
print("\n")
print(classification_report(y_test,y_pred))

print("Training set score for RFC: %f" % final_rfc.score(X_train_norm, y_train))
print("Testing  set score for RFC: %f" % final_rfc.score(X_test_norm  , y_test))

# Best performance with Random Forest Classifier: 94%
# Out:
# Best score for training data: 0.976905311778291
#
# Best #estimators: 140
#
# Best max depth: 12
#
# [[77  2]
#  [ 1 29]]
#
#
#               precision    recall  f1-score   support
#
#           -1       0.99      0.97      0.98        79
#            1       0.94      0.97      0.95        30
#
#     accuracy                           0.97       109
#    macro avg       0.96      0.97      0.97       109
# weighted avg       0.97      0.97      0.97       109
#
# Training set score for RFC: 1.000000
# Testing  set score for RFC: 0.972477

# %%
import xgboost as xgb
y_train_0 = y_train + 1
y_test_0 = y_test + 1
xg_train = xgb.DMatrix(X_train_norm, label=y_train_0)
xg_test = xgb.DMatrix(X_test_norm, label=y_test_0)
# setup parameters for xgboost
param = {}
# use softmax multi-class classification
param['objective'] = 'multi:softmax'
# scale weight of positive examples
param['eta'] = 0.15
param['max_depth'] = 10
param['silent'] = 1
param['nthread'] = 4
param['num_class'] = 3

watchlist = [(xg_train, 'train'), (xg_test, 'test')]
num_round = 15
bst = xgb.train(param, xg_train, num_round, watchlist)
# get prediction
pred = bst.predict(xg_test)
error_rate = np.sum(pred != y_test_0) / y_test_0.shape[0]
print('Test error using softmax = {}'.format(error_rate))

# do the same thing again, but output probabilities
param['objective'] = 'multi:softprob'
bst = xgb.train(param, xg_train, num_round, watchlist)
# Note: this convention has been changed since xgboost-unity
# get prediction, this is in 1D array, need reshape to (ndata, nclass)
pred_prob = bst.predict(xg_test).reshape(y_test_0.shape[0], 3)
pred_label = np.argmax(pred_prob, axis=1)
error_rate = np.sum(pred_label != y_test_0) / y_test_0.shape[0]
print('Test error using softprob = {}'.format(error_rate))

cm = confusion_matrix(y_test_0, pred)

print(cm)
print("\n")
print(classification_report(y_test_0,pred))

print("Testing  set score for XGBoost: %f" % ((y_test_0 == pred).sum() / y_test_0.size) )
# Out:
# [0]	train-merror:0.009238	test-merror:0.036697
# [1]	train-merror:0.004619	test-merror:0.036697
# [2]	train-merror:0.006928	test-merror:0.027523
# [3]	train-merror:0.004619	test-merror:0.027523
# [4]	train-merror:0	test-merror:0.027523
# [5]	train-merror:0	test-merror:0.027523
# [6]	train-merror:0	test-merror:0.027523
# [7]	train-merror:0	test-merror:0.027523
# [8]	train-merror:0	test-merror:0.027523
# [9]	train-merror:0	test-merror:0.027523
# [10]	train-merror:0	test-merror:0.027523
# [11]	train-merror:0	test-merror:0.027523
# [12]	train-merror:0	test-merror:0.027523
# [13]	train-merror:0	test-merror:0.027523
# [14]	train-merror:0	test-merror:0.027523
# [15]	train-merror:0	test-merror:0.027523
# [16]	train-merror:0	test-merror:0.027523
# [17]	train-merror:0	test-merror:0.027523
# [18]	train-merror:0	test-merror:0.027523
# [19]	train-merror:0	test-merror:0.027523
# [20]	train-merror:0	test-merror:0.027523
# [21]	train-merror:0	test-merror:0.027523
# [22]	train-merror:0	test-merror:0.027523
# [23]	train-merror:0	test-merror:0.027523
# [24]	train-merror:0	test-merror:0.027523
# [25]	train-merror:0	test-merror:0.036697
# [26]	train-merror:0	test-merror:0.036697
# [27]	train-merror:0	test-merror:0.036697
# [28]	train-merror:0	test-merror:0.036697
# [29]	train-merror:0	test-merror:0.036697
# Test error using softmax = 0.03669724770642202
# [0]	train-merror:0.009238	test-merror:0.036697
# [1]	train-merror:0.004619	test-merror:0.036697
# [2]	train-merror:0.006928	test-merror:0.027523
# [3]	train-merror:0.004619	test-merror:0.027523
# [4]	train-merror:0	test-merror:0.027523
# [5]	train-merror:0	test-merror:0.027523
# [6]	train-merror:0	test-merror:0.027523
# [7]	train-merror:0	test-merror:0.027523
# [8]	train-merror:0	test-merror:0.027523
# [9]	train-merror:0	test-merror:0.027523
# [10]	train-merror:0	test-merror:0.027523
# [11]	train-merror:0	test-merror:0.027523
# [12]	train-merror:0	test-merror:0.027523
# [13]	train-merror:0	test-merror:0.027523
# [14]	train-merror:0	test-merror:0.027523
# [15]	train-merror:0	test-merror:0.027523
# [16]	train-merror:0	test-merror:0.027523
# [17]	train-merror:0	test-merror:0.027523
# [18]	train-merror:0	test-merror:0.027523
# [19]	train-merror:0	test-merror:0.027523
# [20]	train-merror:0	test-merror:0.027523
# [21]	train-merror:0	test-merror:0.027523
# [22]	train-merror:0	test-merror:0.027523
# [23]	train-merror:0	test-merror:0.027523
# [24]	train-merror:0	test-merror:0.027523
# [25]	train-merror:0	test-merror:0.036697
# [26]	train-merror:0	test-merror:0.036697
# [27]	train-merror:0	test-merror:0.036697
# [28]	train-merror:0	test-merror:0.036697
# [29]	train-merror:0	test-merror:0.036697
# Test error using softprob = 0.03669724770642202
# [[76  3]
#  [ 1 29]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97        79
#            2       0.91      0.97      0.94        30
#
#     accuracy                           0.96       109
#    macro avg       0.95      0.96      0.95       109
# weighted avg       0.96      0.96      0.96       109
#
# Testing  set score for XGBoost: 0.963303

# %%
# DNN Classifier
# One hot encode labels
from sklearn.preprocessing import LabelEncoder
OH_encoder = LabelEncoder()
OH_y_train = pd.DataFrame(OH_encoder.fit_transform(y_train))
OH_y_test = pd.DataFrame(OH_encoder.transform(y_test))
y_train_oh = keras.utils.to_categorical(OH_y_train)
y_test_oh = keras.utils.to_categorical(OH_y_test)

# Callbacks and plot functions
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.plot(hist['epoch'], hist['accuracy'],
           label='Train Accuracy')
  plt.plot(hist['epoch'], hist['val_accuracy'],
           label = 'Val Accuracy')
  plt.legend()

early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.0005, patience=10, restore_best_weights=True)
rlrop = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', min_delta=0.001, patience=5, verbose=1, mode='auto')

# %%
# DNN model for classification
# Define Model 1 - Small "shallow" 1-hidden-layer model
def build_model1(dropout, l1,l2):
  model = keras.Sequential([
    layers.Dense(800, activation=tf.nn.relu,kernel_regularizer=keras.regularizers.l1_l2(l1,l2), input_shape=[len(X_train_norm.keys())]),
    layers.Dropout(dropout),
    layers.BatchNormalization(),  
    layers.Dense(200,activation=tf.nn.relu, kernel_regularizer=keras.regularizers.l1_l2(l1,l2)),
    layers.Dropout(dropout),
    layers.BatchNormalization(),
    layers.Dense(2,activation=tf.nn.softmax)
  ])

  optimizer = tf.keras.optimizers.Adam(0.001)

  model.compile(loss='categorical_crossentropy',
                optimizer=optimizer,
                metrics=['accuracy'])
  return model

model = build_model1(0.5,0.0001,0.0001)
EPOCHS = 150
history = model.fit(X_train_norm, y_train_oh, epochs=EPOCHS,
                    validation_split = 0.2, verbose=1, callbacks=[early_stop, rlrop,PrintDot()])

plot_history(history)

test_loss, test_acc = model.evaluate(np.array(X_test_norm), y_test_oh, verbose=0)
print(test_loss,test_acc)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 346 samples, validate on 87 samples
# Epoch 1/150
# 320/346 [==========================>...] - ETA: 0s - loss: 13.7128 - accuracy: 0.8188
# 346/346 [==============================] - 8s 23ms/sample - loss: 13.6019 - accuracy: 0.8266 - val_loss: 11.8866 - val_accuracy: 0.9655
# Epoch 2/150
# 346/346 [==============================] - 6s 17ms/sample - loss: 11.2069 - accuracy: 0.9075 - val_loss: 10.1633 - val_accuracy: 0.9770
# Epoch 3/150
# 346/346 [==============================] - 6s 18ms/sample - loss: 9.5652 - accuracy: 0.9364 - val_loss: 8.5520 - val_accuracy: 0.9655
# Epoch 4/150
# 346/346 [==============================] - 5s 16ms/sample - loss: 8.0525 - accuracy: 0.9306 - val_loss: 7.1923 - val_accuracy: 0.9655
# Epoch 5/150
# 346/346 [==============================] - 6s 18ms/sample - loss: 6.8087 - accuracy: 0.9422 - val_loss: 6.0880 - val_accuracy: 0.9655
# Epoch 6/150
# 346/346 [==============================] - 5s 16ms/sample - loss: 5.7458 - accuracy: 0.9711 - val_loss: 5.2055 - val_accuracy: 0.9885
# Epoch 7/150
# 346/346 [==============================] - 6s 17ms/sample - loss: 5.0230 - accuracy: 0.9480 - val_loss: 4.6103 - val_accuracy: 0.9655
# Epoch 8/150
# 346/346 [==============================] - 5s 15ms/sample - loss: 4.4432 - accuracy: 0.9624 - val_loss: 4.1250 - val_accuracy: 0.9885
# Epoch 9/150
# 346/346 [==============================] - 5s 15ms/sample - loss: 4.0624 - accuracy: 0.9509 - val_loss: 3.8552 - val_accuracy: 0.9655
# Epoch 10/150
# 346/346 [==============================] - 5s 15ms/sample - loss: 3.7791 - accuracy: 0.9509 - val_loss: 4.1861 - val_accuracy: 0.7931
# Epoch 11/150
# 346/346 [==============================] - 6s 16ms/sample - loss: 3.5225 - accuracy: 0.9509 - val_loss: 4.1624 - val_accuracy: 0.7471
# Epoch 12/150
# 346/346 [==============================] - 6s 16ms/sample - loss: 3.3138 - accuracy: 0.9653 - val_loss: 3.2533 - val_accuracy: 0.9655
# Epoch 13/150
# 288/346 [=======================>......] - ETA: 0s - loss: 3.2107 - accuracy: 0.9479
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-8ef5602a4155> in <module>
#      22 EPOCHS = 150
#      23 history = model.fit(X_train_norm, y_train_oh, epochs=EPOCHS,
# ---> 24                     validation_split = 0.2, verbose=1, callbacks=[early_stop, rlrop,PrintDot()])
#      25
#      26 plot_history(history)
#
# ~\Anaconda3\envs\tensorflow_2\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     732         max_queue_size=max_queue_size,
#     733         workers=workers,
# --> 734         use_multiprocessing=use_multiprocessing)
#     735
#     736   def evaluate(self,
#
# ~\Anaconda3\envs\tensorflow_2\lib\site-packages\tensorflow_core\python\keras\engine\training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     672         validation_steps=validation_steps,
#     673         validation_freq=validation_freq,
# --> 674         steps_name='steps_per_epoch')
#     675
#     676   def evaluate(self,
#
# ~\Anaconda3\envs\tensorflow_2\lib\site-packages\tensorflow_core\python\keras\engine\training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     391
#     392         # Get outputs.
# --> 393         batch_outs = f(ins_batch)
#     394         if not isinstance(batch_outs, list):
#     395           batch_outs = [batch_outs]
#
# ~\Anaconda3\envs\tensorflow_2\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3623         value = math_ops.cast(value, tensor.dtype)
#    3624       converted_inputs.append(value)
# -> 3625     outputs = self._graph_fn(*converted_inputs)
#    3626
#    3627     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~\Anaconda3\envs\tensorflow_2\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1079       TypeError: For invalid positional/keyword argument combinations.
#    1080     """
# -> 1081     return self._call_impl(args, kwargs)
#    1082
#    1083   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~\Anaconda3\envs\tensorflow_2\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1119       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1120           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1121     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1122
#    1123   def _filtered_call(self, args, kwargs):
#
# ~\Anaconda3\envs\tensorflow_2\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# ~\Anaconda3\envs\tensorflow_2\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# ~\Anaconda3\envs\tensorflow_2\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
# Define Model 2 - Medium model
def build_model2():
  model = keras.Sequential([
    layers.Dense(8000, activation=tf.nn.relu, input_shape=[len(X_train_norm.keys())]),
    layers.Dense(1000,activation=tf.nn.relu),
    layers.Dense(200,activation=tf.nn.relu),
    layers.Dense(50,activation=tf.nn.relu),
    layers.Dense(2,activation=tf.nn.softmax)
  ])

  optimizer = tf.keras.optimizers.Adam(0.001)

  model.compile(loss='categorical_crossentropy',
                optimizer=optimizer,
                metrics=['accuracy'])
  return model

model2 = build_model2()
EPOCHS = 1000
history2 = model2.fit(X_train_norm, y_train_oh, epochs=EPOCHS,
                    validation_split = 0.2, verbose=0, callbacks=[early_stop, rlrop, PrintDot()])

plot_history(history2)
test_loss2, test_acc2 = model2.evaluate(X_test_norm, y_test_oh)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
#
# ..........
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# ..........
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# .WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# 109/109 [==============================] - 4s 37ms/sample - loss: 4.4362 - accuracy: 0.7248

# %%
# Define Model 2 - Medium model
def build_model3(dropout: int, l1: int, l2: int):
    model = keras.Sequential([
        layers.Dense(1000, activation=tf.nn.relu ,kernel_regularizer=keras.regularizers.l1_l2(l1,l2), input_shape=[len(X_train_norm.keys())]),
        layers.Dropout(dropout),
        layers.BatchNormalization(),  
        layers.Dense(20,activation=tf.nn.relu, kernel_regularizer=keras.regularizers.l1_l2(l1,l2)),
        layers.Dropout(dropout),
        layers.BatchNormalization(),
        layers.Dense(2,activation=tf.nn.softmax)
  ])

    optimizer = tf.keras.optimizers.Adam(0.001)

    model.compile(loss='categorical_crossentropy',
                optimizer=optimizer,
                metrics=['accuracy'])
    return model

model2 = build_model3(0.5,0.0001,0.0001)
EPOCHS = 100
history2 = model2.fit(X_train_norm, y_train_oh, epochs=EPOCHS, batch_size=64,
                    validation_split = 0.2, verbose=1, callbacks=[early_stop, rlrop, PrintDot()])

plot_history(history2)
test_loss2, test_acc2 = model2.evaluate(X_test_norm, y_test_oh)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 346 samples, validate on 87 samples
# Epoch 1/100
# 320/346 [==========================>...] - ETA: 0s - loss: 17.1811 - accuracy: 0.6250
# 346/346 [==============================] - 6s 17ms/sample - loss: 17.0654 - accuracy: 0.6329 - val_loss: 16.3138 - val_accuracy: 0.7586
# Epoch 2/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 14.1944 - accuracy: 0.8092 - val_loss: 12.7774 - val_accuracy: 0.9310
# Epoch 3/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 11.9778 - accuracy: 0.8439 - val_loss: 10.7928 - val_accuracy: 0.9540
# Epoch 4/100
# 346/346 [==============================] - 5s 13ms/sample - loss: 10.3567 - accuracy: 0.8699 - val_loss: 9.2273 - val_accuracy: 0.9540
# Epoch 5/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 8.8429 - accuracy: 0.8873 - val_loss: 7.8143 - val_accuracy: 0.9540
# Epoch 6/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 7.5276 - accuracy: 0.9249 - val_loss: 6.6929 - val_accuracy: 0.9655
# Epoch 7/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 6.4396 - accuracy: 0.9306 - val_loss: 5.7421 - val_accuracy: 0.9540
# Epoch 8/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 5.5751 - accuracy: 0.9364 - val_loss: 4.9595 - val_accuracy: 0.9655
# Epoch 9/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 4.7822 - accuracy: 0.9624 - val_loss: 4.3603 - val_accuracy: 0.9655
# Epoch 10/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 4.2157 - accuracy: 0.9393 - val_loss: 3.8663 - val_accuracy: 0.9770
# Epoch 11/100
# 346/346 [==============================] - 4s 13ms/sample - loss: 3.7684 - accuracy: 0.9422 - val_loss: 3.6460 - val_accuracy: 0.9195
# Epoch 12/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 3.4235 - accuracy: 0.9566 - val_loss: 3.3291 - val_accuracy: 0.9655
# Epoch 13/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 3.1583 - accuracy: 0.9595 - val_loss: 3.1580 - val_accuracy: 0.8851
# Epoch 14/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 2.9613 - accuracy: 0.9509 - val_loss: 2.7979 - val_accuracy: 0.9655
# Epoch 15/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 2.7816 - accuracy: 0.9538 - val_loss: 3.1211 - val_accuracy: 0.7931
# Epoch 16/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 2.7033 - accuracy: 0.9538 - val_loss: 3.0385 - val_accuracy: 0.8161
# Epoch 17/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 2.6250 - accuracy: 0.9711 - val_loss: 2.7420 - val_accuracy: 0.9195
# Epoch 18/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 2.5693 - accuracy: 0.9509 - val_loss: 2.7393 - val_accuracy: 0.8736
# Epoch 19/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 2.4995 - accuracy: 0.9740 - val_loss: 2.5083 - val_accuracy: 0.9885
# Epoch 20/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 2.4345 - accuracy: 0.9480 - val_loss: 2.3794 - val_accuracy: 0.9885
# Epoch 21/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 2.3730 - accuracy: 0.9538 - val_loss: 2.5037 - val_accuracy: 0.9310
# Epoch 22/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 2.4097 - accuracy: 0.9711 - val_loss: 2.8517 - val_accuracy: 0.8506
# Epoch 23/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 2.3748 - accuracy: 0.9595 - val_loss: 2.8023 - val_accuracy: 0.8276
# Epoch 24/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 2.3229 - accuracy: 0.9711 - val_loss: 2.3400 - val_accuracy: 0.9655
# Epoch 25/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 2.3735 - accuracy: 0.9566 - val_loss: 2.4001 - val_accuracy: 0.9770
# Epoch 26/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 2.5214 - accuracy: 0.9451 - val_loss: 2.6162 - val_accuracy: 0.9885
# Epoch 27/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 2.7113 - accuracy: 0.9306 - val_loss: 2.7356 - val_accuracy: 0.9770
# Epoch 28/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 2.7832 - accuracy: 0.9595 - val_loss: 2.9110 - val_accuracy: 0.9770
# Epoch 29/100
# 320/346 [==========================>...] - ETA: 0s - loss: 2.8305 - accuracy: 0.9594
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 346/346 [==============================] - 5s 14ms/sample - loss: 2.8326 - accuracy: 0.9538 - val_loss: 2.8209 - val_accuracy: 0.9655
# Epoch 30/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 2.7676 - accuracy: 0.9682 - val_loss: 2.7405 - val_accuracy: 0.9770
# Epoch 31/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 2.6510 - accuracy: 0.9711 - val_loss: 2.6364 - val_accuracy: 0.9885
# Epoch 32/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 2.5412 - accuracy: 0.9798 - val_loss: 2.5329 - val_accuracy: 0.9770
# Epoch 33/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 2.4413 - accuracy: 0.9682 - val_loss: 2.4271 - val_accuracy: 0.9770
# Epoch 34/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 2.3436 - accuracy: 0.9740 - val_loss: 2.3235 - val_accuracy: 0.9770
# Epoch 35/100
# 346/346 [==============================] - 5s 14ms/sample - loss: 2.2288 - accuracy: 0.9855 - val_loss: 2.2426 - val_accuracy: 0.9770
# Epoch 36/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 2.1456 - accuracy: 0.9769 - val_loss: 2.1764 - val_accuracy: 0.9770
# Epoch 37/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 2.0785 - accuracy: 0.9740 - val_loss: 2.1017 - val_accuracy: 0.9770
# Epoch 38/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 1.9931 - accuracy: 0.9827 - val_loss: 2.0265 - val_accuracy: 0.9770
# Epoch 39/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 1.9371 - accuracy: 0.9855 - val_loss: 1.9546 - val_accuracy: 0.9770
# Epoch 40/100
# 346/346 [==============================] - 4s 13ms/sample - loss: 1.8654 - accuracy: 0.9855 - val_loss: 1.8976 - val_accuracy: 0.9770
# Epoch 41/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 1.8166 - accuracy: 0.9798 - val_loss: 1.8399 - val_accuracy: 0.9770
# Epoch 42/100
# 346/346 [==============================] - 4s 13ms/sample - loss: 1.7713 - accuracy: 0.9827 - val_loss: 1.8085 - val_accuracy: 0.9770
# Epoch 43/100
# 346/346 [==============================] - 5s 14ms/sample - loss: 1.7118 - accuracy: 0.9769 - val_loss: 1.7639 - val_accuracy: 0.9770
# Epoch 44/100
# 346/346 [==============================] - 5s 14ms/sample - loss: 1.6586 - accuracy: 0.9855 - val_loss: 1.6956 - val_accuracy: 0.9770
# Epoch 45/100
# 346/346 [==============================] - 5s 14ms/sample - loss: 1.6332 - accuracy: 0.9711 - val_loss: 1.6559 - val_accuracy: 0.9770
# Epoch 46/100
# 346/346 [==============================] - 4s 13ms/sample - loss: 1.6209 - accuracy: 0.9682 - val_loss: 1.6118 - val_accuracy: 0.9885
# Epoch 47/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 1.5833 - accuracy: 0.9740 - val_loss: 1.6321 - val_accuracy: 0.9770
# Epoch 48/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 1.5387 - accuracy: 0.9855 - val_loss: 1.5942 - val_accuracy: 0.9770
# Epoch 49/100
# 346/346 [==============================] - 4s 13ms/sample - loss: 1.5097 - accuracy: 0.9827 - val_loss: 1.5454 - val_accuracy: 0.9770
# Epoch 50/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 1.4640 - accuracy: 0.9884 - val_loss: 1.5189 - val_accuracy: 0.9770
# Epoch 51/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 1.4257 - accuracy: 0.9827 - val_loss: 1.4769 - val_accuracy: 0.9770
# Epoch 52/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 1.3900 - accuracy: 0.9855 - val_loss: 1.4570 - val_accuracy: 0.9770
# Epoch 53/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 1.3546 - accuracy: 0.9884 - val_loss: 1.4369 - val_accuracy: 0.9770
# Epoch 54/100
# 346/346 [==============================] - 4s 11ms/sample - loss: 1.3238 - accuracy: 0.9884 - val_loss: 1.4564 - val_accuracy: 0.9310
# Epoch 55/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 1.2862 - accuracy: 0.9913 - val_loss: 1.4548 - val_accuracy: 0.8966
# Epoch 56/100
# 346/346 [==============================] - 4s 12ms/sample - loss: 1.2529 - accuracy: 0.9827 - val_loss: 1.3595 - val_accuracy: 0.9655
# Epoch 57/100
# 346/346 [==============================] - 4s 13ms/sample - loss: 1.2310 - accuracy: 0.9827 - val_loss: 1.2793 - val_accuracy: 0.9770
# Epoch 58/100
# 346/346 [==============================] - 5s 13ms/sample - loss: 1.1941 - accuracy: 0.9827 - val_loss: 1.2364 - val_accuracy: 0.9770
# Epoch 59/100
# 346/346 [==============================] - 5s 14ms/sample - loss: 1.1684 - accuracy: 0.9855 - val_loss: 1.2143 - val_accuracy: 0.9885
# Epoch 60/100
# 346/346 [==============================] - 5s 15ms/sample - loss: 1.1446 - accuracy: 0.9798 - val_loss: 1.1993 - val_accuracy: 0.9885
# Epoch 61/100
# 346/346 [==============================] - 5s 14ms/sample - loss: 1.1176 - accuracy: 0.9971 - val_loss: 1.1934 - val_accuracy: 0.9655
# Epoch 62/100
# 346/346 [==============================] - 5s 15ms/sample - loss: 1.1074 - accuracy: 0.9827 - val_loss: 1.1751 - val_accuracy: 0.9770
# Epoch 63/100
# 346/346 [==============================] - 5s 15ms/sample - loss: 1.0813 - accuracy: 0.9942 - val_loss: 1.1630 - val_accuracy: 0.9770
# Epoch 64/100
# 346/346 [==============================] - 5s 14ms/sample - loss: 1.0556 - accuracy: 0.9942 - val_loss: 1.1451 - val_accuracy: 0.9885
# Epoch 65/100
# 346/346 [==============================] - 5s 15ms/sample - loss: 1.0664 - accuracy: 0.9711 - val_loss: 1.1163 - val_accuracy: 0.9770
# Epoch 66/100
# 346/346 [==============================] - 5s 15ms/sample - loss: 1.0539 - accuracy: 0.9942 - val_loss: 1.0971 - val_accuracy: 0.9885
# Epoch 67/100
# 346/346 [==============================] - 5s 15ms/sample - loss: 1.0405 - accuracy: 0.9827 - val_loss: 1.1205 - val_accuracy: 0.9655
# Epoch 68/100
# 346/346 [==============================] - 5s 15ms/sample - loss: 1.0426 - accuracy: 0.9798 - val_loss: 1.1593 - val_accuracy: 0.8966
# Epoch 69/100
# 346/346 [==============================] - 5s 15ms/sample - loss: 1.0306 - accuracy: 0.9855 - val_loss: 1.0943 - val_accuracy: 0.9655
# Epoch 70/100
# 346/346 [==============================] - 5s 15ms/sample - loss: 1.0163 - accuracy: 0.9855 - val_loss: 1.0906 - val_accuracy: 0.9425
# Epoch 71/100
# 346/346 [==============================] - 5s 14ms/sample - loss: 1.0016 - accuracy: 0.9913 - val_loss: 1.0279 - val_accuracy: 0.9770
# Epoch 72/100
# 346/346 [==============================] - 5s 15ms/sample - loss: 1.0101 - accuracy: 0.9827 - val_loss: 1.0048 - val_accuracy: 0.9770
# Epoch 73/100
# 346/346 [==============================] - 5s 15ms/sample - loss: 0.9966 - accuracy: 0.9798 - val_loss: 0.9981 - val_accuracy: 0.9885
# Epoch 74/100
# 346/346 [==============================] - 5s 14ms/sample - loss: 0.9907 - accuracy: 0.9798 - val_loss: 0.9787 - val_accuracy: 0.9885
# Epoch 75/100
# 346/346 [==============================] - 5s 14ms/sample - loss: 0.9690 - accuracy: 0.9913 - val_loss: 0.9971 - val_accuracy: 0.9885
# Epoch 76/100
# 346/346 [==============================] - 5s 14ms/sample - loss: 0.9660 - accuracy: 0.9769 - val_loss: 0.9890 - val_accuracy: 0.9885
# Epoch 77/100
# 346/346 [==============================] - 5s 15ms/sample - loss: 0.9811 - accuracy: 0.9740 - val_loss: 1.0143 - val_accuracy: 0.9770
# Epoch 78/100
# 346/346 [==============================] - 5s 14ms/sample - loss: 0.9580 - accuracy: 0.9798 - val_loss: 1.0473 - val_accuracy: 0.9195
# Epoch 79/100
# 320/346 [==========================>...] - ETA: 0s - loss: 0.9516 - accuracy: 0.9875
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 346/346 [==============================] - 5s 15ms/sample - loss: 0.9507 - accuracy: 0.9855 - val_loss: 1.0706 - val_accuracy: 0.8621
# Epoch 80/100
# 346/346 [==============================] - 5s 15ms/sample - loss: 0.9445 - accuracy: 0.9827 - val_loss: 1.0642 - val_accuracy: 0.8736
# Epoch 81/100
# 346/346 [==============================] - 6s 17ms/sample - loss: 0.9399 - accuracy: 0.9827 - val_loss: 1.0492 - val_accuracy: 0.8966
# Epoch 82/100
# 346/346 [==============================] - 5s 15ms/sample - loss: 0.9435 - accuracy: 0.9740 - val_loss: 1.0264 - val_accuracy: 0.8966
# Epoch 83/100
# 346/346 [==============================] - 5s 15ms/sample - loss: 0.8924 - accuracy: 0.9913 - val_loss: 1.0059 - val_accuracy: 0.9080
# Epoch 84/100
# 320/346 [==========================>...] - ETA: 0s - loss: 0.8939 - accuracy: 0.9875
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 346/346 [==============================] - 6s 17ms/sample - loss: 0.8935 - accuracy: 0.9884 - val_loss: 0.9873 - val_accuracy: 0.9080
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# 109/109 [==============================] - 6s 56ms/sample - loss: 1.0221 - accuracy: 0.9725

# %%
## Best model: 0.5, 0.0001,0.0001
