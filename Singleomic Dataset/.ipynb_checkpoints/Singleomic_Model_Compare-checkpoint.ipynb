# %% [markdown]
# ### Evaluation of the different latent spaces obtained with the different models.
# - PCA
# - KPCA
# - AE
# - DAE

# %%
import Models
import numpy as np
import random as rn
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

rn.seed(1)
np.random.seed(1)
tf.random.set_seed(1)
tf.config.threading.set_inter_op_parallelism_threads(1)
tf.config.threading.set_intra_op_parallelism_threads(1)

# Load Data
X_renal_data = pd.read_csv('./x_exp_renal.csv', sep='\t') # Dataset has Donor ID as first column
y_renal_data = pd.read_csv('./y_renal.csv', sep=',') # Dataset has Donor ID on first column and Label on second column.

X_train_norm, X_train_swapped, X_test_norm, y_train, y_test, y_train_oh, y_test_oh, X_train_first, X_train_second, X_swapped_first, X_swapped_second, X_test_first, X_test_second \
    = Models.prepare_datasets(X_renal_data.iloc[:,1:],y_renal_data["label"], test_size=0.2, swap_noise=0.15)

# X_train_norm is the training dataset, normalized, that we will use to fit PCA, KPCA and the AE. 
# X_train_swapped is the same dataset with "swap noise", that we will use to fit the DAE.
# Out:
# swapping: 65 rows.

# %%
import importlib
importlib.reload(Models)
# Out:
# <module 'Models' from 'C:\\Desarrollo\\Data Science\\Jupyter Notebooks\\Stage\\oss-stage-2019\\Singleomic Dataset\\Models.py'>

# %%
## Perform PCA
X_latent_pca, X_latent_test_pca = Models.perform_PCA(X_train_norm, X_test_norm, y_train, y_test, n_components=50)
## Perform KPCA
X_latent_kpca, X_latent_test_kpca = Models.perform_KPCA(X_train_norm, X_test_norm, y_train, y_test, n_components=50, kernel="rbf", gamma=0.008)
## Build and Train Autoencoder
autoencoder, encoder, decoder, loss = Models.build_and_train_autoencoder(X_train_norm,
                                                                  X_train_norm,
                                                                  encoding_dim=50, 
                                                                  regularizer=tf.keras.regularizers.l1_l2(0,0.000005),
                                                                  dropout=0.1,
                                                                  epochs=90)

X_latent_ae = Models.encode_dataset(X_train_norm, encoder)
X_latent_test_ae = Models.encode_dataset(X_test_norm, encoder)
## Build and Train Denoising Autoencoder
d_autoencoder, d_encoder, d_decoder, d_loss = Models.build_and_train_autoencoder(X_train_swapped,
                                                                         X_train_norm, 
                                                                         encoding_dim=50, 
                                                                         regularizer=tf.keras.regularizers.l1_l2(0.00001,0.00005),
                                                                         dropout=0.1,
                                                                         epochs=90)
X_latent_dae = Models.encode_dataset(X_train_norm, d_encoder)
X_latent_test_dae = Models.encode_dataset(X_test_norm, d_encoder)

# Latent Representations:
# - PCA: X_latent_pca, X_latent_test_pca
# - KPCA: X_latent_kpca, X_latent_test_kpca
# - AE: X_latent_ae, X_latent_test_ae
# - DAE: X_latent_dae, X_latent_test_dae
# Out:
# PCA on single-modal explained variance ratio: 0.6460561619179183
# 0.7128692970423495
# Compression: 102.52
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 00068: early stopping
# Compression: 102.52
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# ...

# %%
print(X_latent_pca.shape)
print(X_latent_kpca.shape)
print(X_latent_ae.shape)
print(X_latent_dae.shape)
# Out:
# (433, 50)
# (433, 50)
# (433, 50)
# (433, 50)

# %%
### CLASSIFICATION ###
# We use the reduced datasets to train a classifier and compare them.
original_classify = Models.classify_with_cv(X_train_norm, X_test_norm, y_train, y_test, model_type="Original")
# PCA Classification
pca_classify = Models.classify_with_cv(X_latent_pca, X_latent_test_pca, y_train, y_test, model_type="PCA")
# KPCA Classification
kpca_classify = Models.classify_with_cv(X_latent_kpca, X_latent_test_kpca, y_train, y_test, model_type="KPCA")
# AE Classification
ae_classify = Models.classify_with_cv(X_latent_ae, X_latent_test_ae, y_train, y_test, model_type="AE")
# DAE Classification
dae_classify = Models.classify_with_cv(X_latent_dae, X_latent_test_dae, y_train, y_test, model_type="DAE")
# Out:
# Results for PCA:
# C:\Users\Tomas\Anaconda3\envs\tensorflow_2\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ZeroDivisionError: float division by zero
#
#   FitFailedWarning)
# C:\Users\Tomas\Anaconda3\envs\tensorflow_2\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ZeroDivisionError: float division by zero
#
#   FitFailedWarning)
# C:\Users\Tomas\Anaconda3\envs\tensorflow_2\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ZeroDivisionError: float division by zero
#
#   FitFailedWarning)
# ...

# %%
###### CLUSTERING ###
# MAP y_train from classes -1 and 1 to 0 and 1
y_train_map = ((y_train + 1)/2).astype(int)
original_clustering = Models.cluster(X_train_norm, y_train_map, model_type="Original")
# PCA Clustering
pca_clustering = Models.cluster(X_latent_pca, y_train_map, model_type="PCA")
# KPCA Clustering
kpca_clustering = Models.cluster(X_latent_kpca, y_train_map, model_type="KPCA")
# AE Clustering
ae_clustering = Models.cluster(X_latent_ae, y_train_map, model_type="AE")
# DAE Clustering
dae_clustering = Models.cluster(X_latent_dae, y_train_map, model_type="DAE")
# Out:
# mutual information: 0.0003339088774655787
# PCA 2 clusters -  silhoutte score: 0.5621789737597149
# PCA 3 clusters -  silhoutte score: 0.1638544280842594
# PCA 4 clusters -  silhoutte score: 0.15796669565460633
# PCA 5 clusters -  silhoutte score: 0.15983231098915068
# PCA 6 clusters -  silhoutte score: 0.15460431305969827
# mutual information: 0.002398954736070857
# PCA 2 clusters -  silhoutte score: 0.6843303738167211
# PCA 3 clusters -  silhoutte score: 0.6435678309029708
# PCA 4 clusters -  silhoutte score: 0.6435678309029708
# C:\Users\Tomas\Anaconda3\envs\tensorflow_2\lib\site-packages\sklearn\cluster\_k_means.py:296: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   ).fit(X, sample_weight=sample_weight)
# ...

# %%
results = [original_classify + original_clustering, pca_classify + pca_clustering, kpca_classify + kpca_clustering, ae_classify + ae_clustering, dae_classify + dae_clustering]
scores = pd.DataFrame(results, index=["PCA","KPCA","AE","DAE"],
                      columns=["LR_accuracy","SVM_accuracy", "RF_accuracy", "LR_auc", "SVM_auc", "RF_auc","kmeans_silhouette","kmeans_mutual_info","spectral_silhouette","spectral_mutual_info","hierarchical_silhouette","hierarchical_mutual_info"])    
scores
# Out:
#       LR_accuracy  SVM_accuracy  RF_accuracy    LR_auc   SVM_auc    RF_auc  \
# PCA      0.963303      0.963303     0.935780  0.984810  0.983122  0.980802
# KPCA     0.770642      0.871560     0.917431  0.978481  0.981857  0.979325
# AE       0.963303      0.963303     0.963303  0.985232  0.983966  0.982700
# DAE      0.899083      0.908257     0.917431  0.975949  0.969198  0.973418
#
#       kmeans_silhouette  kmeans_mutual_info  spectral_silhouette  \
# PCA            0.562179            0.000334             0.684330
# KPCA           0.561404            0.000484             0.563064
# AE             0.410353            0.000484             0.562496
# DAE            0.666514            0.000665             0.667022
#
#       spectral_mutual_info  hierarchical_silhouette  hierarchical_mutual_info
# PCA               0.002399                 0.560827                  0.000070
# KPCA              0.000665                 0.561404                  0.000484
# ...
