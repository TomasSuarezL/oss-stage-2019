# %%
import Models
import numpy as np
import random as rn
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

rn.seed(1)
np.random.seed(1)
tf.random.set_seed(1)
tf.config.threading.set_inter_op_parallelism_threads(1)
tf.config.threading.set_intra_op_parallelism_threads(1)

# Load Data
X_renal_data = pd.read_csv('./x_exp_renal.csv', sep='\t') # Dataset has Donor ID as first column
y_renal_data = pd.read_csv('./y_renal.csv', sep=',') # Dataset has Donor ID on first column and Label on second column.

X_train_norm, X_train_swapped, X_test_norm, y_train, y_test, y_train_oh, y_test_oh, X_train_first, X_train_second, X_swapped_first, X_swapped_second, X_test_first, X_test_second \
    = Models.prepare_datasets(X_renal_data.iloc[:,1:],y_renal_data["label"], test_size=0.2, swap_noise=0.15)
# Out:
# swapping: 65 rows.

# %%
import importlib
importlib.reload(Models)
# Out:
# <module 'Models' from 'C:\\Desarrollo\\Data Science\\Jupyter Notebooks\\Stage\\oss-stage-2019\\Singleomic Dataset\\Models.py'>

# %%
###  Hyperparamter tuning
# MAP y_train from classes -1 and 1 to 0 and 1
y_train_map = ((y_train + 1)/2).astype(int)

### VISUALIZATION WITH PCA
## ORIGINAL DATASET
X_latent_pca, X_latent_test_pca = Models.perform_PCA(X_train_norm, X_test_norm, y_train, y_test, n_components=10)

mus=[0.7]
dropouts = [0.1]
l1s = [0.000005]
l2s = [0.000005]
scores = []
for dropout in dropouts:
    for l1 in l1s:
        for l2 in l2s:
            for mu in mus:
                ## Build and Train Autoencoder
                autoencoder, encoder, decoder, loss = Models.build_and_train_multi_autoencoder([X_swapped_first,X_swapped_second],
                                                                              [X_train_first,X_train_second],
                                                                              encoding_dim=50, 
                                                                              regularizer=tf.keras.regularizers.l1_l2(l1,l2),
                                                                              dropout=dropout,
                                                                              epochs=200,
                                                                              mu=mu)
                ## Encode datasets
                X_latent_ae = Models.encode_dataset([X_train_first,X_train_second], encoder)
                X_latent_test_ae = Models.encode_dataset([X_test_first,X_test_second], encoder)

                ## PCA ON AUTOENCODER LATENT SPACE
                X_latent_pca_ae, X_latent_test_pca_ae = Models.perform_PCA(X_latent_ae, X_latent_test_ae, y_train, y_test, n_components=10)

                ### CLASSIFICATION ###
                classify = Models.classify_with_cv(X_latent_ae, X_latent_test_ae, y_train, y_test, model_type="AE")

                ### CLUSTERING ###
                clustering = Models.cluster(X_latent_ae,y_train_map, model_type="AE")

                scores.append([mu,dropout,l1,l2,loss] + classify + clustering)
# Out:
# PCA on single-modal explained variance ratio: 0.48103795292302987
# Compression: 102.52
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'pandas.core.frame.DataFrame'>"}), <class 'NoneType'>
# Train on 433 samples
# Epoch 1/200
# 433/433 [==============================] - 1s 3ms/sample - loss: 0.2673 - model_53_loss: 0.1422 - model_53_1_loss: 0.1471 - model_53_mse: 0.1438 - model_53_1_mse: 0.1484
# Epoch 2/200
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.1532 - model_53_loss: 0.0541 - model_53_1_loss: 0.0638 - model_53_mse: 0.0550 - model_53_1_mse: 0.0649
# Epoch 3/200
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0943 - model_53_loss: 0.0178 - model_53_1_loss: 0.0206 - model_53_mse: 0.0179 - model_53_1_mse: 0.0207
# Epoch 4/200
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.
200
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0105 - model_53_loss: 0.0082 - model_53_1_loss: 0.0083 - model_53_mse: 0.0082 - model_53_1_mse: 0.0083
# Epoch 71/200
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0105 - model_53_loss: 0.0082 - model_53_1_loss: 0.0083 - model_53_mse: 0.0082 - model_53_1_mse: 0.0083
# Epoch 72/200
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0104 - model_53_loss: 0.0082 - model_53_1_loss: 0.0083 - model_53_mse: 0.0082 - model_53_1_mse: 0.0083
# Epoch 73/200
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0105 - model_53_loss: 0.0084 - model_53_1_loss: 0.0085 - model_53_mse: 0.0083 - model_53_1_mse: 0.0084
# Epoch 74/200
# 433/433 [==============================] - 1s 1ms/sample - loss: 0.0104 - model_53_loss: 0.0083 - model_53_1_loss: 0.0083 - model_53_mse: 0.0083 - model_53_1_mse: 0.0083
# Epoch 75/200
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0105 - model_53_loss: 0.0084 - model_53_1_loss: 0.0084 - model_53_mse: 0.0083 - model_53_1_mse: 0.0084
# Epoch 76/200
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0105 - model_53_loss: 0.0085 - model_53_1_loss: 0.0085 - model_53_mse: 0.0084 - model_53_1_mse: 0.0084
# Epoch 77/200
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0104 - model_53_loss: 0.0082 - model_53_1_loss: 0.0083 - model_53_mse: 0.0082 - model_53_1_mse: 0.0083
# Epoch 78/200
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0104 - model_53_loss: 0.0082 - model_53_1_loss: 0.0082 - model_53_mse: 0.0083 - model_53_1_mse: 0.0083
# Epoch 79/200
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0105 - model_53_loss: 0.0083 - model_53_1_loss: 0.0084 - model_53_mse: 0.0083 - model_53_1_mse: 0.0084 0s - loss: 0.0114 - model_53_loss: 0.0092 - model_53_1_loss: 0.0094 - model_53_mse: 0.0092 - model_53_1_
# Epoch 80/200
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0104 - model_53_loss: 0.0082 - model_53_1_loss: 0.0083 - model_53_mse: 0.0082 - model_53_1_mse: 0.0083
# Epoch 81/200
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0104 - model_53_loss: 0.0083 - model_53_1_loss: 0.0084 - model_53_mse: 0.0083 - model_53_1_mse: 0.0084
# Epoch 82/200
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.0104 - model_53_loss: 0.0081 - model_53_1_loss: 0.0082 - model_53_mse: 0.0082 - model_53_1_mse: 0.0083
# Epoch 00082: early stopping
# 0.010354053220490109
# PCA on single-modal explained variance ratio: 0.9920591115951538
# Results for AE:
# C:\Users\Tomas\Anaconda3\envs\tensorflow_2\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ZeroDivisionError: float division by zero
#
#   FitFailedWarning)
# C:\Users\Tomas\Anaconda3\envs\tensorflow_2\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ZeroDivisionError: float division by zero
#
#   FitFailedWarning)
# C:\Users\Tomas\Anaconda3\envs\tensorflow_2\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ZeroDivisionError: float division by zero
#
#   FitFailedWarning)
# C:\Users\Tomas\Anaconda3\envs\tensorflow_2\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ZeroDivisionError: float division by zero
#
#   FitFailedWarning)
# C:\Users\Tomas\Anaconda3\envs\tensorflow_2\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ZeroDivisionError: float division by zero
#
#   FitFailedWarning)
# Best score for training data: 0.9561881849772789
#
# Best C: 0.1
# [[76  3]
#  [ 3 27]]
#
#
#               precision    recall  f1-score   support
#
#           -1       0.96      0.96      0.96        79
#            1       0.90      0.90      0.90        30
#
#     accuracy                           0.94       109
#    macro avg       0.93      0.93      0.93       109
# weighted avg       0.94      0.94      0.94       109
#
# Training set score for Logistic Regression: 0.960739
# Testing  set score for Logistic Regression: 0.944954
# Best score for training data: 0.9631114675220529
#
# Best C: 0.5
#
# Best Gamma: 0.5
# [[76  3]
#  [ 2 28]]
#
#
#               precision    recall  f1-score   support
#
#           -1       0.97      0.96      0.97        79
#            1       0.90      0.93      0.92        30
#
#     accuracy                           0.95       109
#    macro avg       0.94      0.95      0.94       109
# weighted avg       0.95      0.95      0.95       109
#
# Training set score for SVM: 0.965358
# Testing  set score for SVM: 0.954128
# Best score for training data: 0.9515370221865812
#
# Best #estimators: 100
#
# Best max depth: 10
# [[76  3]
#  [ 1 29]]
#
#
#               precision    recall  f1-score   support
#
#           -1       0.99      0.96      0.97        79
#            1       0.91      0.97      0.94        30
#
#     accuracy                           0.96       109
#    macro avg       0.95      0.96      0.95       109
# weighted avg       0.96      0.96      0.96       109
#
# Training set score for RFC: 1.000000
# Testing  set score for RFC: 0.963303
# mutual information: 0.33904922662747755
# AE 2 clusters -  silhoutte score: 0.4807034134864807
# AE 3 clusters -  silhoutte score: 0.4911934733390808
# AE 4 clusters -  silhoutte score: 0.3665817677974701
# AE 5 clusters -  silhoutte score: 0.3722074031829834
# AE 6 clusters -  silhoutte score: 0.37699759006500244
# mutual information: 0.0014019244204848628
# AE 2 clusters -  silhoutte score: 0.5370741486549377
# AE 3 clusters -  silhoutte score: 0.5363007187843323
# AE 4 clusters -  silhoutte score: 0.5255661010742188
# AE 5 clusters -  silhoutte score: 0.5011962056159973
# AE 6 clusters -  silhoutte score: 0.4892529845237732
# mutual information: 0.478123713277538
# AE 2 clusters -  silhoutte score: 0.47304800152778625
# AE 3 clusters -  silhoutte score: 0.4893326759338379
# AE 4 clusters -  silhoutte score: 0.352193146944046
# AE 5 clusters -  silhoutte score: 0.349735826253891
# AE 6 clusters -  silhoutte score: 0.3558177351951599

# %%
scores = pd.DataFrame(scores,
                      columns=["mu","dropout","l1","l2","loss","LR_accuracy","SVM_accuracy", "RF_accuracy", "LR_auc", "SVM_auc", "RF_auc","kmeans_silhouette","kmeans_mutual_info","spectral_silhouette","spectral_mutual_info","hierarchical_silhouette","hierarchical_mutual_info"])    
scores
# Out:
#     mu  dropout        l1        l2      loss  LR_accuracy  SVM_accuracy  \
# 0  0.7      0.1  0.000005  0.000005  0.010354     0.944954      0.954128
#
#    RF_accuracy    LR_auc   SVM_auc    RF_auc  kmeans_silhouette  \
# 0     0.963303  0.977637  0.978059  0.981857           0.480703
#
#    kmeans_mutual_info  spectral_silhouette  spectral_mutual_info  \
# 0            0.339049             0.537074              0.001402
#
#    hierarchical_silhouette  hierarchical_mutual_info
# 0                 0.473048                  0.478124

# %% [markdown]
# ### Results
#
# | dim | mu  | l1      | l2      | Dropout | Loss   | Accuracy (LR) | Accuracy (SVM) | Accuracy (RF) | ROC-AUC (LR) | ROC-AUC (SVM) | ROC-AUC (RF) | SS (K-means) | MI (K-means) | SS (Spectral) | MI (Spectral) | SS (Hierarch.) | MI (Hierarch.) |
# |-----|-----|---------|---------|---------|--------|---------------|----------------|---------------|--------------|---------------|--------------|--------------|--------------|---------------|---------------|----------------|----------------|
# | 50  | 0.5 | 0.000005| 0.000005| 0.10    | 0.0093 |  0.96         | 0.93           | 0.97          | 0.9814       | 0.9814        | 0.9850       | 0.50         | 0.0004       | 0.51          | 0.0000        | 0.50           | 0.0004         |
# | 50  | 0.5 | 0.000005| 0.000001| 0.00    | 0.0106 |  0.96         | 0.96           | 0.94          | 0.9856       | 0.9839        | 0.9873       | 0.41         | 0.4355       | 0.51          | 0.0047        | 0.40           | 0.4112         |
# |-----|-----|---------|---------|---------|--------|---------------|----------------|---------------|--------------|---------------|--------------|--------------|--------------|---------------|---------------|----------------|----------------|
# | 100 | 0.5 | 0.000005| 0.000001| 0.00    | 0.0087 |  0.95         | 0.94           | 0.98          | 0.9822       | 0.9822        | 0.9824       | 0.55         | 0.0004       | 0.55          | 0.0006        | 0.55           | 0.0004         |
# |-----|-----|---------|---------|---------|--------|---------------|----------------|---------------|--------------|---------------|--------------|--------------|--------------|---------------|---------------|----------------|----------------|
# | 200 | 0.5 | 0.000005| 0.000001| 0.20    | 0.0101 |  0.96         | 0.95           | 0.97          | 0.9810       | 0.9767        | 0.9852       | 0.55         | 0.0015       | 0.50          | 0.0047        | 0.55           | 0.0004         |
# |-----|-----|---------|---------|---------|--------|---------------|----------------|---------------|--------------|---------------|--------------|--------------|--------------|---------------|---------------|----------------|----------------|
# | 20  | 0.5 | 0.000005| 0.000005| 0.00    | 0.0120 |  0.93         | 0.92           | 0.94          | 0.9679       | 0.9721        | 0.9706       | 0.43         | 0.4197       | 0.50          | 0.0033        | 0.50           | 0.0003         |
# | 20  | 0.5 | 0.000005| 0.000005| 0.10    | 0.0110 |  0.94         | 0.93           | 0.94          | 0.9755       | 0.9780        | 0.9755       | 0.52         | 0.0012       | 0.52          | 0.0012        | 0.52           | 0.0004         |
# |-----|-----|---------|---------|---------|--------|---------------|----------------|---------------|--------------|---------------|--------------|--------------|--------------|---------------|---------------|----------------|----------------|
# | 50  | 0.5 | 0.000005| 0.000005| 0.10    | 0.0095 |  0.95         | 0.94           | 0.96          | 0.9793       | 0.9793        | 0.9854       | 0.54         | 0.0006       | 0.55          | 0.0047        | 0.54           | 0.0004         |
# | 50  | 0.7 | 0.000005| 0.000005| 0.10    | 0.0121 |  0.95         | 0.95           | 0.97          | 0.9797       | 0.9797        | 0.9871       | 0.45         | 0.3095       | 0.51          | 0.0006        | 0.44           | 0.4695         |
# |-----|-----|---------|---------|---------|--------|---------------|----------------|---------------|--------------|---------------|--------------|--------------|--------------|---------------|---------------|----------------|----------------|
# | 50  | 0.7 | 0.000005| 0.000005| 0.15    | 0.0095 |  0.95         | 0.92           | 0.98          | 0.9810       | 0.9818        | 0.9789       | 0.54         | 0.0008       | 0.53          | 0.0047        | 0.54           | 0.0006         |
# | 50  | 0.9 | 0.000005| 0.000005| 0.10    | 0.0115 |  0.94         | 0.95           | 0.96          | 0.9793       | 0.9801        | 0.9793       | 0.51         | 0.0004       | 0.51          | 0.0006        | 0.51           | 0.0003         |
# | 50  | 0.9 | 0.000005| 0.000005| 0.15    | 0.0112 |  0.95         | 0.92           | 0.97          | 0.9818       | 0.9831        | 0.9791       | 0.44         | 0.4041       | 0.50          | 0.0008        | 0.44           | 0.4738         |
